# %%
from utils.openai_helpers import query_openai_model, query_openai_model_batch
from utils.wiki_helpers import get_abstraction_nodes, convert_abstraction_qids_to_labels, get_label
from utils.prompt_functions import get_abstraction_mcq_prompt, get_abstraction_mcq_prompt_v2

# %%
import pandas as pd
import json
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np

# %%
# wikidata_properties = {
#     "Geospatial Information": {
#         "Moving Up the Hierarchy": {
#             "Located in the administrative territorial entity": "P131",
#             "Part of": "P361",
#             "Located on terrain feature": "P706"
#         },
#         "Moving Down the Hierarchy": {
#             "Contains administrative territorial entity": "P150",
#             "Location": "P276",
#             "Located on street": "P669"
#         },
#         "Lateral Connections": {
#             "Location": "P276",
#             "Located on terrain feature": "P706"
#         },
#         "General Context": {
#             "Country": "P17",
#             "Instance of": "P31"
#         }
#     },
#     "Occupation and Professional Information": {
#         "Moving Up the Hierarchy": {
#             "Field of work": "P101",
#             "Part of": "P361",
#             "Academic discipline": "P136"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Subclass of": "P279"
#         },
#         "Lateral Connections": {
#             "Employer": "P108",
#             "Member of": "P463",
#             "Affiliation": "P1416"
#         },
#         "General Context": {
#             "Occupation": "P106",
#             "Position held": "P39"
#         }
#     },
#     "Temporal Information": {
#         "Moving Up the Hierarchy": {
#             "Follows": "P155",
#             "Part of": "P361"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Subclass of": "P279"
#         },
#         "Lateral Connections": {
#             "Concurrent with": "P1072",
#             "Followed by": "P156"
#         },
#         "General Context": {
#             "Point in time": "P585",
#             "Duration": "P2047"
#         }
#     },
#     "Biological and Taxonomic Information": {
#         "Moving Up the Hierarchy": {
#             "Parent taxon": "P171",
#             "Part of": "P361"
#         },
#         "Moving Down the Hierarchy": {
#             "Taxon rank": "P105",
#             "Has part": "P527"
#         },
#         "Lateral Connections": {
#             "Related to": "P2789",
#             "Similar to": "P1889"
#         },
#         "General Context": {
#             "Instance of": "P31",
#             "Species": "P105"
#         }
#     },
#     "Cultural and Creative Work": {
#         "Moving Up the Hierarchy": {
#             "Part of the series": "P179",
#             "Genre": "P136"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Subgenre": "P741"
#         },
#         "Lateral Connections": {
#             "Inspired by": "P941",
#             "Derivative work": "P4969"
#         },
#         "General Context": {
#             "Instance of": "P31",
#             "Creative work type": "P1448"
#         }
#     },
#     "Historical and Event Information": {
#         "Moving Up the Hierarchy": {
#             "Part of": "P361",
#             "Significant event": "P793"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Instance of": "P31"
#         },
#         "Lateral Connections": {
#             "Followed by": "P156",
#             "Follows": "P155"
#         },
#         "General Context": {
#             "Point in time": "P585",
#             "Location": "P276"
#         }
#     },
#     "Organizational Information": {
#         "Moving Up the Hierarchy": {
#             "Parent organization": "P749",
#             "Part of": "P361"
#         },
#         "Moving Down the Hierarchy": {
#             "Subsidiary": "P355",
#             "Branch": "P1833"
#         },
#         "Lateral Connections": {
#             "Affiliate": "P1416",
#             "Member of": "P463"
#         },
#         "General Context": {
#             "Industry": "P452",
#             "Instance of": "P31"
#         }
#     },
#     "Literary and Bibliographic Information": {
#         "Moving Up the Hierarchy": {
#             "Part of the series": "P179",
#             "Genre": "P136"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Subgenre": "P741"
#         },
#         "Lateral Connections": {
#             "Inspired by": "P941",
#             "Derivative work": "P4969"
#         },
#         "General Context": {
#             "Instance of": "P31",
#             "Author": "P50"
#         }
#     },
#     "Scientific and Technical Information": {
#         "Moving Up the Hierarchy": {
#             "Field of work": "P101",
#             "Part of": "P361"
#         },
#         "Moving Down the Hierarchy": {
#             "Has part": "P527",
#             "Subclass of": "P279"
#         },
#         "Lateral Connections": {
#             "Related to": "P2789",
#             "Similar to": "P1889"
#         },
#         "General Context": {
#             "Instance of": "P31",
#             "Research topic": "P2579"
#         }
#     },
#     "Social and Demographic Information": {
#         "Moving Up the Hierarchy": {
#             "Part of": "P361",
#             "Member of": "P463"
#         },
#         "Moving Down the Hierarchy": {
#             "Subclass of": "P279",
#             "Has part": "P527"
#         },
#         "Lateral Connections": {
#             "Related to": "P2789",
#             "Similar to": "P1889"
#         },
#         "General Context": {
#             "Instance of": "P31",
#             "Demographic group": "P1448"
#         }
#     }
# }

# %%
wikidata_properties = {
    "Geospatial Information": {
        "Moving Up the Hierarchy": {
            "Located in the administrative territorial entity": "P131",
            "Part of": "P361",
            "Located on terrain feature": "P706"
        },
        "Moving Down the Hierarchy": {
            "Contains administrative territorial entity": "P150",
            "Location": "P276",
            "Located on street": "P669"
        }
    },
    "Occupation and Professional Information": {
        "Moving Up the Hierarchy": {
            "Field of work": "P101",
            "Part of": "P361",
            "Academic discipline": "P136"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Subclass of": "P279"
        }
    },
    "Temporal Information": {
        "Moving Up the Hierarchy": {
            "Follows": "P155",
            "Part of": "P361"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Subclass of": "P279"
        }
    },
    "Biological and Taxonomic Information": {
        "Moving Up the Hierarchy": {
            "Parent taxon": "P171",
            "Part of": "P361"
        },
        "Moving Down the Hierarchy": {
            "Taxon rank": "P105",
            "Has part": "P527"
        }
    },
    "Cultural and Creative Work": {
        "Moving Up the Hierarchy": {
            "Part of the series": "P179",
            "Genre": "P136"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Subgenre": "P741"
        }
    },
    "Historical and Event Information": {
        "Moving Up the Hierarchy": {
            "Part of": "P361",
            "Significant event": "P793"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Instance of": "P31"
        }
    },
    "Organizational Information": {
        "Moving Up the Hierarchy": {
            "Parent organization": "P749",
            "Part of": "P361"
        },
        "Moving Down the Hierarchy": {
            "Subsidiary": "P355",
            "Branch": "P1833"
        }
    },
    "Literary and Bibliographic Information": {
        "Moving Up the Hierarchy": {
            "Part of the series": "P179",
            "Genre": "P136"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Subgenre": "P741"
        }
    },
    "Scientific and Technical Information": {
        "Moving Up the Hierarchy": {
            "Field of work": "P101",
            "Part of": "P361"
        },
        "Moving Down the Hierarchy": {
            "Has part": "P527",
            "Subclass of": "P279"
        }
    },
    "Social and Demographic Information": {
        "Moving Up the Hierarchy": {
            "Part of": "P361",
            "Member of": "P463"
        },
        "Moving Down the Hierarchy": {
            "Subclass of": "P279",
            "Has part": "P527"
        }
    }
}

# %%
df = pd.read_csv('inputs/simple_multihop_examples - examples.csv')

# %%
df
# Out:
#                                    GENERATED_QUESTION     ITEM_1    ITEM_2  \
# 0   What is the seal described by the country that...   Q4871749       Q30
# 1   What is the author of the national anthem of t...   Q5248175      Q145
# 2   What is the main article of the list that is t...    Q669125     Q9726
# 3   What is the geography associated with the coun...   Q3974535  Q1237470
# 4   What is the location of the headquarters of th...   Q1721298     Q2736
# ..                                                ...        ...       ...
# 95  What is the name day associated with the first...     Q76535   Q292691
# 96  What is the head of government of the administ...   Q2084020   Q170578
# 97  What is the currency used by the country that ...   Q7497242     Q1033
# 98  What is the history of the writing system used...   Q6174806  Q5576697
# 99  What is the language of the version for the ot...  Q17579913  Q6298851
#
#        ITEM_3     ITEM_4 PROP_1 PROP_2 PROP_3
# 0     Q171663     Q14213    P17   P418  P2378
# 1      Q40807   Q1606590    P27    P85    P50
# 2    Q3047934    Q207628    P86  P1455   P360
# 3         Q38    Q216989   P175   P495  P2633
# 4     Q253414        Q72   P641  P3719   P159
# ..        ...        ...    ...    ...    ...
# 95      Q2390       Q110   P735  P1750   P361
# 96     Q43783  Q10304754    P19   P131     P6
# 97   Q5440850   Q1485655    P27   P155    P38
# 98      Q8229   Q3772237   P734   P282  P2184
# 99  Q18180970       Q150   P735  P1560   P407
#
# [100 rows x 8 columns]

# %%
# prompts_list = []
# for i in range(len(df)):
#     question = df.iloc[i]['GENERATED_QUESTION']
#     answer_qid = df.iloc[i]['ITEM_4']
#     abstraction_nodes = get_abstraction_nodes(answer_qid, wikidata_properties)
#     abstraction_nodes_names = convert_abstraction_qids_to_labels(abstraction_nodes)
#     combined_abstraction_list = []
#     for key, sub_dict in abstraction_nodes_names.items():
#         for sub_key, value in sub_dict.items():
#             combined_abstraction_list.extend(value)
#     combined_abstraction_list = list(set(combined_abstraction_list))
#     prompt = get_abstraction_mcq_prompt(question, combined_abstraction_list)
#     prompts_list.append(prompt)

# %%
def process_row(index, row, wikidata_properties):
    question = row['GENERATED_QUESTION']
    answer_qid = row['ITEM_4']
    answer = get_label(answer_qid)
    abstraction_nodes = get_abstraction_nodes(answer_qid, wikidata_properties)
    abstraction_nodes_names, mapping_label_to_qid = convert_abstraction_qids_to_labels(abstraction_nodes)
    combined_abstraction_list = list(mapping_label_to_qid.keys())

    
    prompt = get_abstraction_mcq_prompt(question, answer, combined_abstraction_list)
    # print(f"Processed row {index}")
    return index, prompt, mapping_label_to_qid, answer

def generate_prompts_multi(df, wikidata_properties, max_workers=10):
    prompts_dict = {}
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_row, i, df.iloc[i], wikidata_properties): i for i in range(len(df))}
        with tqdm(total=len(df)) as pbar:
            for future in as_completed(futures):
                index, result, mapping_dict_abs, answer = future.result()
                prompts_dict[index] = result, mapping_dict_abs, answer
                pbar.update(1)
    return prompts_dict

# %%
get_label('Q30')
# Out:
# 'United States of America'

# %%
prompts_data = generate_prompts_multi(df, wikidata_properties)
# Out:
# 100%|██████████| 100/100 [03:29<00:00,  2.09s/it]

# %%
print(prompts_data[0][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(prompts_data[0][2])
#
# NameError: name 'prompts_data' is not defined

# %%
process_row(0, df.iloc[0], wikidata_properties)
# Out:
# Processed row 0
# (0,
#  "\nFor the following question, choose all suitable candidates from the provided options that can reasonably asnwer the question:\n\nQuestion: \nWhat is the seal described by the country that hosted the Battle of Mobley's Meeting House issued by?\n\nOptions:\n['United States Cabinet', 'United States of America', 'public office', 'foreign minister', 'secretary of state', 'Secretary of State']\n\nRespond with a JSON object with 'answer' key containing a list of the selected options, or an empty list if no suitable options are present.\n",
#  {'United States Cabinet': 'Q639738',
#   'United States of America': 'Q30',
#   'public office': 'Q294414',
#   'foreign minister': 'Q7330070',
#   'secretary of state': 'Q736559',
#   'Secretary of State': 'Q533501'})

# %%
np.save('inputs/prompts_list_simple_examples2.npy', prompts_data)

# %%
prompts_data = np.load('inputs/prompts_list_simple_examples2.npy', allow_pickle=True).item()

# %%
prompts_list = []
for i in range(len(prompts_data)):
    mapping_dic = prompts_data[i][1]
    answer = prompts_data[i][2]
    combined_abstraction_list = list(mapping_dic.keys())
    question = df.iloc[i]['GENERATED_QUESTION']
    prompt = get_abstraction_mcq_prompt(question, answer, combined_abstraction_list)
    prompts_list.append(prompt)

# %%
print(prompts_list[8])
# Out:
# Given the following question and a valid answer, identify all suitable candidates from the provided options that can also serve as valid answers to the question. Note that there may be multiple correct answers. Only select options that provide a direct answer to the question and adequately satisfy the information sought.
#
# Question:
# What is the occupation of the founder of the university that John Guillim attended?
#
# Valid Answer:
# priest
#
# Options:
# ['religious occupation', 'cleric', 'minister', 'rabbi', 'monk', 'presbyter', 'Christian minister', 'priestess', 'Reverend', 'Catholic priest', 'Latin Catholic priest']
#
# Respond with a JSON object containing a list of the selected options under the key 'answer'. If no suitable options are present, return an empty list.

# %%
print(prompts_data[4][0])
# Out:
# Given the following question and a valid answer, identify all suitable candidates from the provided options that can also serve as valid answers to the question. Note that there may be multiple correct answers. Only select options that provide a direct answer to the question and adequately satisfy the information sought.
#
# Question:
# What is the location of the headquarters of the regulatory authority of the sport that Kai Gehring plays?
#
# Valid Answer:
# Zürich
#
# Options:
# ['Zürich District', 'Greater Zurich Area', 'RZU', 'Zurich metropolitan area', 'Canton of Zürich', 'Kreis 1', 'District 2', 'Kreis 3', 'Kreis 4', 'Kreis 5', 'District 6', 'District 7', 'Kreis 8', 'District 9', 'District 10', 'District 11', 'Kreis 12', 'Switzerland', 'Old Swiss Confederacy', 'Helvetic Republic', 'First French Empire', 'municipality of Switzerland', 'city of Switzerland', 'cantonal capital of Switzerland', 'capital city', 'college town', 'largest city', 'big city', 'Climate Alliance', 'KlimaBündnis-Städte Schweiz', 'International Association for Sports and Leisure Facilities', 'Zurich']
#
# Respond with a JSON object containing a list of the selected options under the key 'answer'. If no suitable options are present, return an empty list.

# %%
prompts = [prompts_data[i][0] for i in range(len(prompts_data))]
mapping_dics = [prompts_data[i][1] for i in range(len(prompts_data))]
answers = [prompts_data[i][2] for i in range(len(prompts_data))]

# %%
mapping_dics
# Out:
# [{'United States Cabinet': 'Q639738',
#   'United States of America': 'Q30',
#   'public office': 'Q294414',
#   'foreign minister': 'Q7330070',
#   'secretary of state': 'Q736559',
#   'Secretary of State': 'Q533501'},
#  {'human': 'Q5', 'poet': 'Q49757', 'composer': 'Q36834', 'writer': 'Q36180'},
#  {'type of work of art': 'Q116474095',
#   'musical work': 'Q2188189',
#   'composer': 'Q36834',
#   'composition': 'Q462437',
#   'musical work/composition': 'Q105543609',
#   'literary composing': 'Q1333743',
#   'music composing': 'Q11895763',
#   'music composition': 'Q105107008'},
#  {'Italy': 'Q38',
#   'geography of geographic location': 'Q46865913',
#   'geography of Europe': 'Q119716'},
#  {'Zürich District': 'Q660732',
#   'Greater Zurich Area': 'Q30998',
#   'RZU': 'Q95080684',
#   'Zurich metropolitan area': 'Q690149',
#   'Canton of Zürich': 'Q11943',
#   'Kreis 1': 'Q445559',
#   'District 2': 'Q456153',
#   'Kreis 3': 'Q675017',
#   'Kreis 4': 'Q677133',
#   'Kreis 5': 'Q460885',
#   'District 6': 'Q456170',
#   'District 7': 'Q456149',
#   'Kreis 8': 'Q677710',
#   'District 9': 'Q456159',
#   'District 10': 'Q456175',
#   'District 11': 'Q870098',
#   'Kreis 12': 'Q657525',
#   'Switzerland': 'Q39',
#   'Old Swiss Confederacy': 'Q435583',
#   'Helvetic Republic': 'Q206696',
#   'First French Empire': 'Q71084',
#   'municipality of Switzerland': 'Q70208',
#   'city of Switzerland': 'Q54935504',
#   'cantonal capital of Switzerland': 'Q14770218',
#   'capital city': 'Q5119',
#   'college town': 'Q1187811',
#   'largest city': 'Q51929311',
#   'big city': 'Q1549591',
#   'Climate Alliance': 'Q1768108',
#   'KlimaBündnis-Städte Schweiz': 'Q1774367',
#   'International Association for Sports and Leisure Facilities': 'Q475646',
#   'Zurich': 'Q230417'},
#  {'United States Cabinet': 'Q639738',
#   'United States of America': 'Q30',
#   'public office': 'Q294414',
#   'foreign minister': 'Q7330070',
#   'secretary of state': 'Q736559',
#   'Secretary of State': 'Q533501'},
#  {'Iraq': 'Q796',
#   'national anthem': 'Q23691',
#   'As-Salam al-Malaki': 'Q18926474'},
#  {'Uusimaa': 'Q5711',
#   'Southern Finland Regional State Administrative Agency': 'Q4354448',
#   'Finland': 'Q33',
#   'Russian Empire': 'Q34266',
#   'Sweden': 'Q34',
#   "Finnish Socialist Workers' Republic": 'Q1811029',
#   'capital city': 'Q5119',
#   'city': 'Q515',
#   'metropolis': 'Q200250',
#   'municipality of Finland': 'Q856076',
#   'big city': 'Q1549591',
#   'port settlement': 'Q2264924',
#   'Helsinki Downtown': 'Q11862147',
#   'North Helsinki': 'Q18661375',
#   'East Helsinki': 'Q3784748',
#   'Creative Cities Network': 'Q1139352',
#   'World Tourism Cities Federation': 'Q67652870',
#   'Helsinki': 'Q607204',
#   'Helsinki sub-region': 'Q940914',
#   'Helsinki metropolitan area': 'Q673425',
#   'Helsinki capital region': 'Q18691387'},
#  {'religious occupation': 'Q63187345',
#   'cleric': 'Q2259532',
#   'minister': 'Q83307',
#   'rabbi': 'Q133485',
#   'monk': 'Q733786',
#   'presbyter': 'Q23035816',
#   'Christian minister': 'Q1423891',
#   'priestess': 'Q6116659',
#   'Reverend': 'Q841594',
#   'Catholic priest': 'Q250867',
#   'Latin Catholic priest': 'Q1469535'},
#  {'Cascia': 'Q20384', 'Italy': 'Q38', 'frazione': 'Q1134686'},
#  {'Andrew and variants': 'Q389',
#   'Andrew': 'Q418630',
#   'male given name': 'Q12308941'},
#  {'medical specialty': 'Q930752',
#   'academic discipline': 'Q11862829',
#   'medicine': 'Q11190',
#   'clinical sciences': 'Q113129019',
#   'pediatrics': 'Q123028',
#   'pharmacy': 'Q614304',
#   'first aid': 'Q133981',
#   'trauma surgery': 'Q338379'},
#  {'Eurasia': 'Q5401',
#   'Ostfeste': 'Q2035462',
#   'Earth': 'Q2',
#   'Northern Hemisphere': 'Q39061',
#   'Northern Europe': 'Q27479',
#   'Northeastern Europe': 'Q1998497',
#   'Southern Europe': 'Q27449',
#   'Southeast Europe': 'Q263686',
#   'Eastern Europe': 'Q27468',
#   'Western Europe': 'Q27496',
#   'Central Europe': 'Q27509',
#   'Southwestern Europe': 'Q50807777',
#   'Northwestern Europe': 'Q1414323',
#   'Italy': 'Q38',
#   'Belgium': 'Q31',
#   'landmass': 'Q205895',
#   'Europa': 'Q3143',
#   'Europe': 'Q345567',
#   'European Union': 'Q458',
#   'part of the world': 'Q2418896',
#   'continent': 'Q5107',
#   'geographic region': 'Q82794',
#   'European studies': 'Q1377029'},
#  {'Marathonas Municipality': 'Q12875721',
#   'Commune of Marathon': 'Q21623432',
#   'Greece': 'Q41',
#   'town': 'Q3957'},
#  {'Essex County': 'Q54076',
#   "Massachusetts House of Representatives' 12th Essex district": 'Q88097551',
#   "Massachusetts House of Representatives' 13th Essex district": 'Q88097604',
#   "Massachusetts Senate's Second Essex district": 'Q88207067',
#   'United States of America': 'Q30',
#   'city in the United States': 'Q1093829'},
#  {'Eurasia': 'Q5401',
#   'Ostfeste': 'Q2035462',
#   'Earth': 'Q2',
#   'Northern Hemisphere': 'Q39061',
#   'Northern Europe': 'Q27479',
#   'Northeastern Europe': 'Q1998497',
#   'Southern Europe': 'Q27449',
#   'Southeast Europe': 'Q263686',
#   'Eastern Europe': 'Q27468',
#   'Western Europe': 'Q27496',
#   'Central Europe': 'Q27509',
#   'Southwestern Europe': 'Q50807777',
#   'Northwestern Europe': 'Q1414323',
#   'Italy': 'Q38',
#   'Belgium': 'Q31',
#   'landmass': 'Q205895',
#   'Europa': 'Q3143',
#   'Europe': 'Q345567',
#   'European Union': 'Q458',
#   'part of the world': 'Q2418896',
#   'continent': 'Q5107',
#   'geographic region': 'Q82794',
#   'European studies': 'Q1377029'},
#  {'Central District': 'Q5060762',
#   'Boyer-Ahmad County': 'Q1278733',
#   'Iran': 'Q794',
#   'city of Iran': 'Q56557504',
#   'big city': 'Q1549591'},
#  {'Province of Rome': 'Q15119',
#   'Papal States': 'Q170174',
#   'Rome': 'Q1558632',
#   'Ancient Rome': 'Q1747689',
#   'Roman Republic': 'Q17167',
#   'Roman Empire': 'Q2277',
#   'Western Roman Empire': 'Q42834',
#   'Metropolitan City of Rome': 'Q18288160',
#   'Municipio I': 'Q550592',
#   'Municipio II': 'Q16494134',
#   'Municipio III': 'Q16003470',
#   'Municipio IV': 'Q16003516',
#   'Municipio V': 'Q16481953',
#   'Municipio VI': 'Q16481961',
#   'Municipio VII': 'Q16481966',
#   'Municipio XV': 'Q16482005',
#   'Municipio VIII': 'Q16495467',
#   'Municipio IX': 'Q16481947',
#   'Municipio X': 'Q16481977',
#   'Municipio XI': 'Q16481986',
#   'Municipio XII': 'Q16481992',
#   'Municipio XIII': 'Q16481997',
#   'Municipio XIV': 'Q16482002',
#   'Italy': 'Q38',
#   'Kingdom of Italy': 'Q172579',
#   'Ostrogothic Kingdom': 'Q583038',
#   'Byzantine Empire': 'Q12544',
#   'Roman Kingdom': 'Q201038',
#   'Vatican City': 'Q237',
#   'capital city': 'Q5119',
#   'border city': 'Q902814',
#   'abolished municipality in Italy': 'Q3685476',
#   'tourist destination': 'Q1200957',
#   'metropolis': 'Q200250',
#   'largest city': 'Q51929311',
#   'college town': 'Q1187811',
#   'big city': 'Q1549591',
#   'commune of Italy': 'Q747074',
#   'Creative Cities Network': 'Q1139352',
#   'League of Historical Cities': 'Q9383972',
#   'Rzym': 'Q7385796',
#   '410 sack of Rome': 'Q1463845',
#   'Sack of Rome': 'Q979633',
#   'siege of Rome': 'Q60794019',
#   'Siege of Rome': 'Q13554386',
#   'Sack of Rome, 1527': 'Q465627',
#   'founding of Rome': 'Q1247524'},
#  {'Republic of Ireland': 'Q27',
#   'United Kingdom': 'Q145',
#   'language': 'Q34770',
#   'modern language': 'Q1288568',
#   'Connacht Irish': 'Q3756705',
#   'Munster Irish': 'Q3778014',
#   'Ulster Irish': 'Q841756',
#   'Goidelic': 'Q56433',
#   'Iriska': 'Q755983',
#   'Hiberno-English': 'Q665624'},
#  {'male given name': 'Q12308941', 'Brendan': 'Q1176147'},
#  {'profession': 'Q28640', 'biologist': 'Q864503'},
#  {'United States of America': 'Q30', 'aspect of history': 'Q17524420'},
#  {'Serbia': 'Q403', 'central bank': 'Q66344'},
#  {'taxon': 'Q16521', 'Accipitridae': 'Q25510', 'genus': 'Q34740'},
#  {'male given name': 'Q12308941', 'hypocorism': 'Q1130279', 'Bill': 'Q257022'},
#  {'human': 'Q5',
#   'American Legion': 'Q468865',
#   'freemasonry': 'Q41726',
#   'Veterans of Foreign Wars': 'Q3556413',
#   'politician': 'Q82955',
#   'judge': 'Q16533',
#   'businessperson': 'Q43845',
#   'military officer': 'Q189290',
#   'diarist': 'Q18939491',
#   'President of the United States': 'Q11696',
#   'Vice President of the United States': 'Q11699',
#   'Governor-General of the Philippines': 'Q1542521',
#   'United States senator': 'Q4416090',
#   'Harry S. Truman': 'Q7492376',
#   'atomic bombings of Hiroshima and Nagasaki': 'Q488',
#   'Relief of Douglas MacArthur': 'Q1344952',
#   'presidency of Harry S. Truman': 'Q2824575'},
#  {'Cyrillic-script alphabet': 'Q867570',
#   'А': 'Q16330',
#   'Б': 'Q16291',
#   'В': 'Q16352',
#   'Г': 'Q16335',
#   'Д': 'Q16347',
#   'Е': 'Q30431',
#   'Ё': 'Q30955',
#   'Ж': 'Q55589',
#   'З': 'Q149076',
#   'И': 'Q82625',
#   'Й': 'Q181450',
#   'К': 'Q82320',
#   'Л': 'Q172000',
#   'М': 'Q179623',
#   'Н': 'Q174069',
#   'О': 'Q178213',
#   'П': 'Q82553',
#   'Р': 'Q181460',
#   'С': 'Q179873',
#   'Т': 'Q182438',
#   'У': 'Q179867',
#   'Ф': 'Q174289',
#   'Х': 'Q179860',
#   'Ц': 'Q179855',
#   'Ч': 'Q173915',
#   'Ш': 'Q173928',
#   'Щ': 'Q182330',
#   'Ъ': 'Q211299',
#   'Ы': 'Q191528',
#   'Ь': 'Q201499',
#   'Э': 'Q191695',
#   'Ю': 'Q186250',
#   'Я': 'Q188756',
#   'Cyrillic script': 'Q8209'},
#  {'Latin Grammy Awards': 'Q921469',
#   'United States of America': 'Q30',
#   'class of award': 'Q38033430'},
#  {'taxon': 'Q16521', 'Accipitridae': 'Q25510', 'genus': 'Q34740'},
#  {'female given name': 'Q11879590', 'Josefa': 'Q6280302'},
#  {'Argentina': 'Q414', 'coat of arms': 'Q14659'},
#  {'empire': 'Q48349',
#   'culture': 'Q11042',
#   'historical period': 'Q11514315',
#   'historical country': 'Q3024240',
#   'Angkor 333': 'Q540011'},
#  {'Australia': 'Q408', 'history of a city': 'Q28747937'},
#  {'Alameda County': 'Q107146',
#   'United States of America': 'Q30',
#   'big city': 'Q1549591',
#   'city in the United States': 'Q1093829',
#   'sanctuary city': 'Q3559093',
#   'charter city': 'Q13218391',
#   'county seat': 'Q62049',
#   'Oakland': 'Q228113'},
#  {'electrical grid': 'Q1096907',
#   'ground wire': 'Q352170',
#   'overhead power line conductor': 'Q1816195',
#   'power cable': 'Q1939150',
#   'high-voltage power line': 'Q18562917',
#   'industrial building': 'Q1662011',
#   'overhead contact line': 'Q110701',
#   'electrical cable': 'Q188447'},
#  {'perimeter': 'Q28474',
#   'area': 'Q11500',
#   'convex cyclic quadrilateral': 'Q117400683',
#   'equiangular polygon': 'Q2543717',
#   'hyperrectangle': 'Q3801534',
#   'isosceles trapezoid': 'Q1194115',
#   'parallelogram': 'Q45867',
#   'right trapezoid': 'Q12218380',
#   'Hjelmslev quadrilateral': 'Q98098744',
#   'graph theory': 'Q131476'},
#  {'praetorian prefecture of Gaul': 'Q1232541',
#   'Roman Empire': 'Q2277',
#   'Ancient Rome': 'Q1747689',
#   'Roman province': 'Q182547',
#   'Fosse Way': 'Q1233334',
#   'Stanegate': 'Q1510781',
#   'Ermine Street': 'Q1355961',
#   'Kingdom of Brycheiniog': 'Q954585',
#   'Kingdom of Dyfed': 'Q956451',
#   'Kingdom of Ceredigion': 'Q2578706',
#   'Brittany': 'Q327',
#   'province of Brittany': 'Q18415117'},
#  {'sports competition': 'Q13406554',
#   'sport': 'Q349',
#   'sports discipline': 'Q2312410',
#   'Spanish-style bullfighting': 'Q2640883',
#   'The Ride': 'Q29581183',
#   'سباق': 'Q54894541'},
#  {'Bangladesh': 'Q902',
#   'award': 'Q618779',
#   'group of awards': 'Q107655869',
#   'Independence Award in Independence and Liberation War': 'Q61358302',
#   'Independence Award in Science and Technology': 'Q61358183',
#   'Independence Award in Medicine': 'Q61358209',
#   'Independence Award in Education': 'Q61358332',
#   'Independence Award in Literature': 'Q61358110',
#   'Independence Award in Culture': 'Q61358180',
#   'Independence Award in Sports': 'Q61358300',
#   'Independence Award in Rural Development': 'Q61358185',
#   'Independence Award in Social Services': 'Q61358060',
#   'Independence Award in Population Control': 'Q61358233',
#   'Independence Award in Public Administration': 'Q61358417',
#   'Independence Award in Research and Training': 'Q61358449',
#   'Independent Award in Journalism': 'Q58428752',
#   'Independence Award in Language and Independence Movement': 'Q61359175',
#   'Independence Award in Economics': 'Q61360356',
#   'Independence Award in Food Security': 'Q61361980'},
#  {'Royal coat of arms of Great Britain': 'Q7375053',
#   'royal coat of arms of the United Kingdom': 'Q165762',
#   'United Kingdom': 'Q145',
#   'coat of arms': 'Q14659'},
#  {'United Kingdom': 'Q145',
#   'United Kingdom of Great Britain and Ireland': 'Q174193',
#   'parliament': 'Q35749',
#   'bicameral legislature': 'Q189445',
#   'House of Commons': 'Q11005',
#   'House of Lords': 'Q11007',
#   'monarch of the United Kingdom': 'Q9134365',
#   'Parliament of Great Britain': 'Q2739604',
#   'Court of Referees': 'Q108923374'},
#  {'Latin-script alphabet': 'Q29575627',
#   'A': 'Q9659',
#   'B': 'Q9705',
#   'C': 'Q9820',
#   'D': 'Q9884',
#   'E': 'Q9907',
#   'F': 'Q9765',
#   'G': 'Q9739',
#   'H': 'Q9914',
#   'I': 'Q9893',
#   'J': 'Q9773',
#   'K': 'Q9922',
#   'L': 'Q9927',
#   'M': 'Q9933',
#   'N': 'Q9937',
#   'O': 'Q9941',
#   'P': 'Q9946',
#   'Q': 'Q9950',
#   'R': 'Q9852',
#   'S': 'Q9956',
#   'T': 'Q9813',
#   'U': 'Q9747',
#   'V': 'Q9963',
#   'W': 'Q9964',
#   'X': 'Q9968',
#   'Y': 'Q9973',
#   'Z': 'Q9751',
#   'Latin script': 'Q8229'},
#  {'United Kingdom': 'Q145', 'geography of geographic location': 'Q46865913'},
#  {'subclass': 'Q5867051',
#   'superorder': 'Q5868144',
#   'grandorder': 'Q6462265',
#   'mirorder': 'Q7506274',
#   'class': 'Q37517',
#   'rank in zoology': 'Q13578154',
#   'rank in botany': 'Q3100180',
#   'taxonomic rank': 'Q427626',
#   'Rząd': 'Q24704850'},
#  {'India': 'Q668',
#   'Hills and Barak Valley division': 'Q5763489',
#   'Central Assam division': 'Q55606826',
#   'Lower Assam division': 'Q16911447',
#   'North Assam division': 'Q7053976',
#   'Upper Assam division': 'Q7898464',
#   'state of India': 'Q12443800',
#   'Assam': 'Q57156445'},
#  {'male given name': 'Q12308941',
#   'hypocorism': 'Q1130279',
#   'Lenny': 'Q14159489'},
#  {'male given name': 'Q12308941', 'Allan': 'Q406781'},
#  {'aspect of history': 'Q17524420'},
#  {'time zone named for a UTC offset': 'Q17272482'},
#  {'municipal flag': 'Q21850100'},
#  {'Earth-Moon system': 'Q18589965',
#   'inner Solar System': 'Q7879772',
#   'circumstellar habitable zone': 'Q215913',
#   'Milky Way': 'Q321',
#   'Local Group': 'Q3944',
#   'terrestrial planet': 'Q128207',
#   'inner planet of the Solar System': 'Q3504248',
#   'narrative location': 'Q105115142',
#   "Earth's crust": 'Q15316',
#   "Earth's core": 'Q193927',
#   'mantle': 'Q101949',
#   'atmosphere of Earth': 'Q3230',
#   "Earth's surface": 'Q1349417',
#   'biospherel': 'Q42762',
#   'hydrosphere': 'Q83169',
#   'lithosphere': 'Q83296',
#   "Earth's magnetic field": 'Q6500960',
#   'continent': 'Q5107',
#   'hemisphere of the Earth': 'Q399984',
#   'Europe': 'Q46',
#   'Asia': 'Q48',
#   'Africa': 'Q15',
#   'Eurasia': 'Q5401',
#   'Americas': 'Q828',
#   'Antarctica': 'Q51',
#   'Australian continent': 'Q3960',
#   'land': 'Q11081619',
#   'soil': 'Q36133',
#   'Earth': 'Q23048336',
#   'terrain': 'Q14524493',
#   'Earth in Adventure Time': 'Q106540863',
#   'Wikivoyage:Joke articles/Earth': 'Q17579785',
#   'Earth science': 'Q8008',
#   'geology': 'Q1069',
#   'geophysics': 'Q46255',
#   'planetary science': 'Q104499'},
#  {'bisexual community': 'Q351403',
#   'LGBT community': 'Q51393',
#   'sexual orientation': 'Q17888',
#   'romantic orientation': 'Q4688879',
#   'non-binary bisexual': 'Q115870499',
#   'female bisexuality': 'Q105079904',
#   'male bisexuality': 'Q105079290',
#   'non-heterosexuality': 'Q339014',
#   'allosexuality': 'Q64737936',
#   'multisexuality': 'Q106589379',
#   'ambiphilia': 'Q50810374',
#   'bi-curious': 'Q255155',
#   'pansexuality': 'Q271534',
#   'bisociality': 'Q106667104'},
#  {'aspect of history': 'Q17524420',
#   'XYZ Affair': 'Q266994',
#   'study of history': 'Q1066186'},
#  {'human': 'Q5',
#   'Jan Kochanowski University': 'Q3551420',
#   'politician': 'Q82955',
#   'Voivodeship marshal': 'Q1558362',
#   'member of the Sejm of the Republic of Poland': 'Q19269361',
#   'member of the European Parliament': 'Q27169'},
#  {'epifamily': 'Q10296147',
#   'suborder': 'Q5867959',
#   'order': 'Q36602',
#   'group': 'Q83306',
#   'taxonomic rank': 'Q427626',
#   'rank in zoology': 'Q13578154',
#   'rank in botany': 'Q3100180',
#   'gene family': 'Q2278983',
#   'family': 'Q8436',
#   'ichnofamily': 'Q115227428',
#   'Rodina': 'Q2161157',
#   'oofamily': 'Q125838324'},
#  {'United States Cabinet': 'Q639738',
#   'United States of America': 'Q30',
#   'public office': 'Q294414',
#   'foreign minister': 'Q7330070',
#   'secretary of state': 'Q736559',
#   'Secretary of State': 'Q533501'},
#  {'human': 'Q5',
#   'journalist': 'Q1930187',
#   'entrepreneur': 'Q131524',
#   'politician': 'Q82955',
#   'mayor of Bergamo': 'Q73509685',
#   'member of the Regional Council of Lombardy': 'Q47530307'},
#  {'taxon': 'Q16521', 'Accipitridae': 'Q25510', 'genus': 'Q34740'},
#  {'subclass': 'Q5867051',
#   'superorder': 'Q5868144',
#   'grandorder': 'Q6462265',
#   'mirorder': 'Q7506274',
#   'class': 'Q37517',
#   'rank in zoology': 'Q13578154',
#   'rank in botany': 'Q3100180',
#   'taxonomic rank': 'Q427626',
#   'Rząd': 'Q24704850'},
#  {'Julian calendar': 'Q11184',
#   'Gregorian calendar': 'Q12138',
#   'Swedish calendar': 'Q1130275',
#   'calendar month': 'Q47018901',
#   'August 1': 'Q2788',
#   'August 2': 'Q2785',
#   'August 3': 'Q2786',
#   'August 4': 'Q2784',
#   'August 5': 'Q2783',
#   'August 6': 'Q2787',
#   'August 7': 'Q2781',
#   'August 8': 'Q2780',
#   'August 9': 'Q2782',
#   'August 10': 'Q2779',
#   'August 11': 'Q2778',
#   'August 12': 'Q2777',
#   'August 13': 'Q2776',
#   'August 14': 'Q2775',
#   'August 15': 'Q2774',
#   'August 16': 'Q2812',
#   'August 17': 'Q2827',
#   'August 18': 'Q2826',
#   'August 19': 'Q2829',
#   'August 20': 'Q2824',
#   'August 21': 'Q2823',
#   'August 22': 'Q2828',
#   'August 23': 'Q2821',
#   'August 24': 'Q2825',
#   'August 25': 'Q2819',
#   'August 26': 'Q2820',
#   'August 27': 'Q2822',
#   'August 28': 'Q2817',
#   'August 29': 'Q2816',
#   'August 30': 'Q2818',
#   'August 31': 'Q2830',
#   'month of the Gregorian calendar': 'Q18602249',
#   'July': 'Q121',
#   'September': 'Q123',
#   'Sierpień': 'Q94438983',
#   'August': 'Q338998'},
#  {'human': 'Q5',
#   'University of Virginia': 'Q213439',
#   'Massachusetts Institute of Technology': 'Q49108',
#   'College of William & Mary': 'Q875637',
#   'American Academy of Arts and Sciences': 'Q463303',
#   'American Philosophical Society': 'Q466089',
#   'American Association for the Advancement of Science': 'Q40358',
#   'National Academy of Sciences': 'Q270794',
#   'physicist': 'Q169470',
#   'university teacher': 'Q1622272',
#   'geologist': 'Q520549',
#   'organizational founder': 'Q4479442',
#   'president': 'Q1255921'},
#  {'human': 'Q5',
#   'politician': 'Q82955',
#   'lawyer': 'Q40348',
#   'Mississippi state representative': 'Q17487661',
#   'Member of the Mississippi Senate': 'Q18195558',
#   'Governor of Mississippi': 'Q878632',
#   'Kentucky General Assembly': 'Q6392265',
#   'United States senator': 'Q4416090'},
#  {'Patrick': 'Q4125649', 'family name': 'Q101352', 'Патрик': 'Q21662574'},
#  {'metaphysics': 'Q35277',
#   'astrophysics': 'Q37547',
#   'branch of science': 'Q2465832',
#   'academic discipline': 'Q11862829',
#   'physics': 'Q413',
#   'cosmogony': 'Q170835'},
#  {'Mexico': 'Q96',
#   'legislature of a Mexican state': 'Q17680584',
#   'unicameral legislature': 'Q37002670',
#   'deputy of the Legislative Assembly of the Federal District': 'Q53544340',
#   'Asamblea de Representantes del Distrito Federal': 'Q5707863',
#   'Congrès de la Ville de Mexico': 'Q59491466'},
#  {'Syria': 'Q858', 'Lebanon': 'Q822', 'mountain range': 'Q46831'},
#  {'Texas': 'Q1439',
#   'San Angelo': 'Q925598',
#   'United States of America': 'Q30',
#   'county of Texas': 'Q11774097'},
#  {'Padua': 'Q617',
#   'ELIXIR Italy': 'Q109496581',
#   'Italy': 'Q38',
#   'university': 'Q3918',
#   'Mediterranean Universities Union': 'Q850927',
#   'Top International Managers in Engineering': 'Q1351882',
#   'Coimbra Group': 'Q211620',
#   'ORCID, Inc.': 'Q19861084',
#   'Confederation of Open Access Repositories': 'Q48789578',
#   'European University Association': 'Q868940',
#   'Netval Research Universities Network': 'Q56063183',
#   'Coalition for Advancing Research Assessment': 'Q115682002',
#   'European Open Science Cloud Association': 'Q125499293',
#   "Biblioteca del Centro di Ateneo per la storia della Resistenza e dell'età contemporanea": 'Q113610914',
#   'Biblioteca medica Vincenzo Pinali. Sezione moderna. Università degli studi di Padova': 'Q16532453',
#   'Beato Pellegrino library': 'Q113013250',
#   'Biblioteca della sede di Bressanone. Università degli studi di Padova': 'Q113295621',
#   'Biblioteca del Centro di cinematografia scientifica ed audiovisivi. Università degli studi di Padova': 'Q113298774',
#   'Biblioteca del Centro internazionale di idrologia della Facoltà di ingegneria. Università degli studi di Padova': 'Q113298775',
#   'Biblioteca centrale di Giurisprudenza. Sezione di diritto privato e critica del diritto. Università degli studi di Padova': 'Q113298778',
#   'Biblioteca centrale di giurisprudenza. Sezione di diritto pubblico internazionale e comunitario. Università degli studi di Padova': 'Q113298779',
#   'Biblioteca centrale di Agripolis Pietro Arduino. Università degli studi di Padova': 'Q113298776',
#   'Biblioteca della Presidenza. Facoltà di giurisprudenza. Università degli studi di Padova': 'Q113298777',
#   'Biblioteca di diritto romano. Università degli studi di Padova': 'Q113298782',
#   'Biblioteca centrale di ingegneria. Università degli studi di Padova': 'Q113298783',
#   'Biblioteca di scienze economiche e aziendali. Università degli studi di Padova': 'Q113298780',
#   'Biblioteca di filosofia del diritto. Università degli studi di Padova': 'Q113298781',
#   "Biblioteca dell'Istituto di storia della medicina della Facoltà di medicina e chirurgia. Università degli studi di Padova": 'Q113298786',
#   'Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Sezione di geofisica. Università degli studi di Padova': 'Q113298787',
#   'Biblioteca di filosofia. Università degli studi di Padova': 'Q113298784',
#   "Biblioteca dell'Istituto di storia del teatro e dello spettacolo della Facoltà di scienze della formazione. Università degli studi di Padova": 'Q113298785',
#   'Biblioteca di scienze politiche Ettore Anchieri. Università degli studi di Padova': 'Q113298790',
#   'Biblioteca di Scienze Statistiche "Bernardo Colombo". Università degli studi di Padova': 'Q113298791',
#   'Biblioteca di matematica. Università degli studi di Padova': 'Q113298788',
#   'Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Università degli studi di Padova': 'Q113298789',
#   'Biblioteca di fisica e astronomia. Sede di fisica. Università degli studi di Padova': 'Q113298794',
#   'Biblioteca di geografia. Università degli studi di Padova': 'Q113298795',
#   'Biblioteca biologico-medica Vallisneri. Università degli studi di Padova': 'Q113298792',
#   'Biblioteca di Scienze del farmaco. Università degli studi di Padova': 'Q113298793',
#   'Biblioteca di storia. Università degli studi di Padova': 'Q113298798',
#   'Biblioteca del Dipartimento di mineralogia e petrologia. Università degli studi di Padova': 'Q113298799',
#   'Biblioteca del Dipartimento di metodi e modelli matematici per le scienze applicate. Università degli studi di Padova': 'Q113298796',
#   'Biblioteca centrale di psicologia Fabio Metelli. Università degli studi di Padova': 'Q113298797',
#   'Biblioteca di Chimica Cesare Pecile. Università degli studi di Padova': 'Q113298802',
#   'Biblioteca del farmaco. Università degli studi di Padova': 'Q113298803',
#   'Biblioteca medica Vincenzo Pinali. Sezione antica della Facoltà di medicina e chirurgia. Università degli studi di Padova': 'Q113298800',
#   "Biblioteca dell'Orto botanico. Università degli studi di Padova": 'Q113298801',
#   "Biblioteca di Scienze dell'Antichità Arte Musica Liviano. Università degli studi di Padova": 'Q113298806',
#   'Biblioteca di neuroscienze. Università degli studi di Padova': 'Q113298807',
#   'Biblioteca centrale di ingegneria. Sede di ingegneria dell\'informazione e ingegneria elettrica "Giovanni Someda". Università degli studi di Padova': 'Q113298804',
#   'Biblioteca di diritto comparato Ruggero Meneghelli. Università degli studi di Padova': 'Q113298805',
#   'Biblioteca medica Vincenzo Pinali. Sezione antica. Università degli studi di Padova': 'Q113298811',
#   'Biblioteca di storia. Università. Università degli studi di Padova': 'Q113298808',
#   'Biblioteca di fisica e astronomia . Sede di astronomia. Università degli studi di Padova': 'Q113298809',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione internazionale. Università degli studi di Padova': 'Q113298814',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione penale. Università degli studi di Padova': 'Q113298815',
#   "Biblioteca P. Cancellieri del Centro di studi e di formazione sui diritti dell'uomo e dei popoli. Università degli studi di Padova": 'Q113298812',
#   'Mediateca del Centro Linguistico di Ateneo. Università degli studi di Padova': 'Q113298813',
#   'Biblioteca di Palazzo Maldura. Sezione Francese. Università degli studi di Padova': 'Q113298818',
#   'Biblioteca di Slavistica e Ungherese. Università degli studi di Padova (Sezione staccata della Biblioteca Maldura)': 'Q113298819',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione tributario. Università degli studi di Padova': 'Q113298816',
#   'Biblioteca del Dipartimento di farmacologia ed anestesiologia E. Meneghetti. Sezione farmacologia. Università degli studi di Padova': 'Q113298817',
#   'Biblioteca di Palazzo Maldura. Sezione Sala riviste. Università degli studi di Padova': 'Q113298820',
#   'Biblioteca centrale di Ingegneria. Sede di tecnica e gestione dei sistemi industriali. Università degli studi di Padova': 'Q113299010',
#   'Biblioteca di astronomia. Osservatorio di astrofisica. Università degli studi di Padova': 'Q113299009',
#   'University of Padua School of Medicine and Surgery': 'Q117000925'},
#  {'Earth': 'Q2',
#   'hemisphere of the Earth': 'Q399984',
#   'Southern Africa': 'Q27394',
#   'Antarctica': 'Q51',
#   'Australia': 'Q408',
#   'South America': 'Q18',
#   'Insular Oceania': 'Q538',
#   'South Atlantic Ocean': 'Q1482804',
#   'Indian Ocean': 'Q1239',
#   'Pacific Ocean': 'Q98',
#   'South Pacific Ocean': 'Q12355425',
#   'Southern Indian Ocean': 'Q108136663',
#   'Global South': 'Q1149903',
#   'Southern Celestial Hemisphere': 'Q2380815'},
#  {'list of public broadcasters by country': 'Q52459877',
#   'United States of America': 'Q30',
#   'radio station': 'Q14350',
#   'international broadcasting': 'Q779239',
#   'online newspaper': 'Q1153191',
#   '501(c)(4) organization': 'Q18325483',
#   'state media': 'Q2324556',
#   'public broadcasting': 'Q26398',
#   'Russian foreign agent law': 'Q17071473',
#   'U.S. Agency for Global Media': 'Q922454'},
#  {'Daïra of Constantine': 'Q3019686',
#   'Algeria': 'Q262',
#   'city': 'Q515',
#   'commune of Algeria': 'Q2989398',
#   'big city': 'Q1549591',
#   'Constantina': 'Q949381',
#   'Siege of Constantine': 'Q3485860'},
#  {'South Africa': 'Q258', 'armed forces': 'Q772547'},
#  {'Washington': 'Q1223',
#   'Colfax': 'Q1509984',
#   'United States of America': 'Q30',
#   'county of Washington': 'Q13415369'},
#  {'East Asia': 'Q27231',
#   'Japanese archipelago': 'Q841337',
#   'Aichi Prefecture': 'Q80434',
#   'Akita Prefecture': 'Q81863',
#   'Aomori Prefecture': 'Q71699',
#   'Chiba Prefecture': 'Q80011',
#   'Fukui Prefecture': 'Q133879',
#   'Fukushima Prefecture': 'Q71707',
#   'Gunma Prefecture': 'Q129499',
#   'Hokkaido': 'Q1037393',
#   'Ibaraki Prefecture': 'Q83273',
#   'Iwate Prefecture': 'Q48326',
#   'Miyagi Prefecture': 'Q47896',
#   'Saitama Prefecture': 'Q128186',
#   'Tochigi Prefecture': 'Q44843',
#   'Tokyo': 'Q1490',
#   'Kanagawa Prefecture': 'Q127513',
#   'Niigata Prefecture': 'Q132705',
#   'Toyama Prefecture': 'Q132929',
#   'Ishikawa Prefecture': 'Q131281',
#   'Yamagata Prefecture': 'Q125863',
#   'Yamanashi Prefecture': 'Q132720',
#   'Nagano Prefecture': 'Q127877',
#   'Gifu Prefecture': 'Q131277',
#   'Shizuoka Prefecture': 'Q131320',
#   'Mie Prefecture': 'Q128196',
#   'Shiga Prefecture': 'Q131358',
#   'Kyoto Prefecture': 'Q120730',
#   'Osaka Prefecture': 'Q122723',
#   'Hyōgo Prefecture': 'Q130290',
#   'Nara Prefecture': 'Q131287',
#   'Wakayama Prefecture': 'Q131314',
#   'Tottori Prefecture': 'Q133935',
#   'Shimane Prefecture': 'Q132751',
#   'Okayama Prefecture': 'Q132936',
#   'Hiroshima Prefecture': 'Q617375',
#   'Yamaguchi Prefecture': 'Q127264',
#   'Tokushima Prefecture': 'Q160734',
#   'Kagawa Prefecture': 'Q161454',
#   'Ehime Prefecture': 'Q123376',
#   'Kōchi Prefecture': 'Q134093',
#   'Fukuoka Prefecture': 'Q123258',
#   'Nagasaki Prefecture': 'Q169376',
#   'Kumamoto Prefecture': 'Q130308',
#   'Oita Prefecture': 'Q133924',
#   'Miyazaki Prefecture': 'Q130300',
#   'Kagoshima Prefecture': 'Q15701',
#   'Okinawa Prefecture': 'Q766445',
#   'Saga Prefecture': 'Q160420',
#   'Japan': 'Q174933',
#   'sovereign state': 'Q3624078',
#   'island country': 'Q112099',
#   'country': 'Q6256',
#   'Northern Japan': 'Q905661',
#   'Eastern Japan': 'Q1063689',
#   'Central Japan': 'Q841336',
#   'Western Japan': 'Q1063946',
#   'Southern Japan': 'Q905991',
#   'Organization for Economic Cooperation and Development': 'Q41550',
#   'G8': 'Q37143',
#   'World Trade Organization': 'Q7825',
#   'G20': 'Q19771',
#   'Asia-Pacific Economic Cooperation': 'Q170481',
#   'United Nations': 'Q1065',
#   'International Bank for Reconstruction and Development': 'Q191384',
#   'International Development Association': 'Q827525',
#   'International Finance Corporation': 'Q656801',
#   'Multilateral Investment Guarantee Agency': 'Q1043527',
#   'International Centre for Settlement of Investment Disputes': 'Q899770',
#   'African Development Bank': 'Q340195',
#   'ASEAN Regional Forum': 'Q7886981',
#   'Asian Development Bank': 'Q188822',
#   'Australia Group': 'Q782942',
#   'League of Nations': 'Q38130',
#   'Missile Technology Control Regime': 'Q1072120',
#   'Interpol': 'Q8475',
#   'Nuclear Suppliers Group': 'Q1480793',
#   'Organisation for the Prohibition of Chemical Weapons': 'Q842490',
#   'International Hydrographic Organization': 'Q233611',
#   'International Energy Agency': 'Q826700',
#   'UNESCO': 'Q7809',
#   'Group on Earth Observations': 'Q5611262',
#   'Universal Postal Union': 'Q17495',
#   'International Telecommunication Union': 'Q376150',
#   'Visa Waiver Program': 'Q45177',
#   'World Meteorological Organization': 'Q170424',
#   'World Health Organization': 'Q7817',
#   'Antarctic Treaty System': 'Q182814',
#   'World Customs Organization': 'Q605326',
#   'Empire of Japan': 'Q188712',
#   'Korean War': 'Q8663',
#   'Treaty of San Francisco': 'Q392541',
#   'Security Treaty Between the United States and Japan': 'Q7445004',
#   'Treaty of Mutual Cooperation and Security Between the United States and Japan': 'Q694604',
#   '1964 Summer Olympics': 'Q8420',
#   "Expo '70": 'Q1119956',
#   '1972 Winter Olympics': 'Q9646',
#   'transfer of sovereignty over Okinawa': 'Q5367188',
#   '1991 Japanese Recession': 'Q17208829',
#   'Great Hanshin Earthquake': 'Q214866',
#   '1998 Winter Olympics': 'Q9664',
#   'Tōkaimura criticality accident': 'Q1377385',
#   '2002 FIFA World Cup': 'Q47735',
#   'Aftermath of the 2011 Tōhoku earthquake and tsunami': 'Q1136168',
#   'Fukushima Daiichi nuclear disaster': 'Q171178',
#   'World War II': 'Q362',
#   '2020 Summer Olympics': 'Q181278',
#   'Japanese studies': 'Q875592'},
#  {'Latin-script alphabet': 'Q29575627',
#   'A': 'Q9659',
#   'B': 'Q9705',
#   'C': 'Q9820',
#   'D': 'Q9884',
#   'E': 'Q9907',
#   'F': 'Q9765',
#   'G': 'Q9739',
#   'H': 'Q9914',
#   'I': 'Q9893',
#   'J': 'Q9773',
#   'K': 'Q9922',
#   'L': 'Q9927',
#   'M': 'Q9933',
#   'N': 'Q9937',
#   'O': 'Q9941',
#   'P': 'Q9946',
#   'Q': 'Q9950',
#   'R': 'Q9852',
#   'S': 'Q9956',
#   'T': 'Q9813',
#   'U': 'Q9747',
#   'V': 'Q9963',
#   'W': 'Q9964',
#   'X': 'Q9968',
#   'Y': 'Q9973',
#   'Z': 'Q9751',
#   'Latin script': 'Q8229'},
#  {'motion picture credits': 'Q4458345',
#   'trailer': 'Q622550',
#   'film frame': 'Q795160',
#   'title sequence': 'Q441606',
#   'audiovisual work': 'Q2431196',
#   'moving image': 'Q10301427',
#   'visual artwork': 'Q4502142',
#   'sequence': 'Q20937557',
#   'film reel': 'Q45871375',
#   'film theory': 'Q28793',
#   'film studies': 'Q1660187',
#   'sociology of film': 'Q3487524'},
#  {'film': 'Q11424',
#   'martial arts film': 'Q1033891',
#   'action film': 'Q188473',
#   'Shaolin vs. Wu-Tang': 'Q3481456'},
#  {'Commonwealth of Nations': 'Q7785',
#   'Lesser Antilles': 'Q93259',
#   'Caribbean': 'Q664609',
#   'Saint George Parish': 'Q1770796',
#   'Saint John Parish': 'Q548816',
#   'Saint Mary Parish': 'Q1999872',
#   'Saint Paul Parish': 'Q386093',
#   'Saint Peter Parish': 'Q1952603',
#   'Saint Philip Parish': 'Q1996895',
#   'Barbuda': 'Q238752',
#   'Redonda': 'Q457261',
#   'Antigua and Barbuda': 'Q781',
#   'state': 'Q7275',
#   'island country': 'Q112099',
#   'country': 'Q6256',
#   'sovereign state': 'Q3624078',
#   'monarchy of Antigua and Barbuda': 'Q3244203',
#   'Commonwealth realm': 'Q202686',
#   'archipelagic state': 'Q13107770',
#   'United Nations': 'Q1065',
#   'World Trade Organization': 'Q7825',
#   'Caribbean Community': 'Q205995',
#   'International Bank for Reconstruction and Development': 'Q191384',
#   'International Finance Corporation': 'Q656801',
#   'Multilateral Investment Guarantee Agency': 'Q1043527',
#   'Organisation of African, Caribbean and Pacific States': 'Q294278',
#   'Agency for the Prohibition of Nuclear Weapons in Latin America and the Caribbean': 'Q3369762',
#   'Alliance of Small Island States': 'Q496967',
#   'Caribbean Development Bank': 'Q3772571',
#   'Interpol': 'Q8475',
#   'Organisation for the Prohibition of Chemical Weapons': 'Q842490',
#   'UNESCO': 'Q7809',
#   'Caribbean Free Trade Association': 'Q5039385',
#   'Universal Postal Union': 'Q17495',
#   'International Telecommunication Union': 'Q376150',
#   'Organization of American States': 'Q123759',
#   'World Meteorological Organization': 'Q170424',
#   'World Health Organization': 'Q7817',
#   'Caribbean Disaster Emergency Management Agency': 'Q5039374',
#   'World Customs Organization': 'Q605326',
#   'West Indies Federation': 'Q652560'},
#  {'Denali Borough': 'Q179950',
#   'Seven Summits': 'Q208126',
#   'Denali National Park and Preserve': 'Q217136',
#   'United States of America': 'Q30',
#   'mountain': 'Q8502',
#   'Denali': 'Q267035'},
#  {'aspect of history': 'Q17524420'},
#  {'subculture': 'Q264965',
#   'chav': 'Q1432214',
#   'association football kit': 'Q1381731'},
#  {'United States Cabinet': 'Q639738',
#   'United States of America': 'Q30',
#   'public office': 'Q294414',
#   'foreign minister': 'Q7330070',
#   'secretary of state': 'Q736559',
#   'Secretary of State': 'Q533501'},
#  {'human': 'Q5', 'writer': 'Q36180', 'poet': 'Q49757', 'lyricist': 'Q822146'},
#  {'Portugal': 'Q45',
#   'Brazil': 'Q155',
#   'Spain': 'Q29',
#   'Angola': 'Q916',
#   'Cape Verde': 'Q1011',
#   'Taiwan': 'Q865',
#   'East Timor': 'Q574',
#   'Guinea-Bissau': 'Q1007',
#   'Mozambique': 'Q1029',
#   'São Tomé and Príncipe': 'Q1039',
#   'language': 'Q34770',
#   'modern language': 'Q1288568',
#   'European Portuguese': 'Q922399',
#   'Barranquenho': 'Q2982964',
#   'Brazilian Portuguese': 'Q750553',
#   'Angolan Portuguese': 'Q2994901',
#   'Guinean Portuguese': 'Q5616512',
#   'Mozambican Portuguese': 'Q4373398',
#   'Cape Verdean Portuguese': 'Q5035141',
#   'São Tomean Portuguese': 'Q7665714',
#   'Macanese Portuguese': 'Q9290867',
#   'East Timorese Portuguese': 'Q4373396',
#   'Portuguese language in Goa': 'Q10352067',
#   'Galician-Portuguese': 'Q9080204',
#   'Portuguese studies': 'Q1721024'},
#  {'aspect of history': 'Q17524420',
#   'XYZ Affair': 'Q266994',
#   'study of history': 'Q1066186'},
#  {'Newfoundland and Labrador': 'Q2003',
#   'Quebec': 'Q176',
#   'Canada': 'Q16',
#   'mountain range': 'Q46831'},
#  {'phase of human life': 'Q785260',
#   'age of a person': 'Q185836',
#   'artistic theme': 'Q1406161',
#   'cultural creation': 'Q119268920',
#   'early childhood': 'Q3377398',
#   'occurrence': 'Q1190554',
#   'parturition': 'Q34581',
#   'adolescence': 'Q131774',
#   'preadolescence': 'Q719723',
#   'Childhood': 'Q47508159',
#   'sociology of childhood': 'Q113884118',
#   'developmental psychology': 'Q175002'},
#  {'aspect of history': 'Q17524420'},
#  {'praetorian prefecture of Gaul': 'Q1232541',
#   'Roman Empire': 'Q2277',
#   'Ancient Rome': 'Q1747689',
#   'Roman province': 'Q182547',
#   'Fosse Way': 'Q1233334',
#   'Stanegate': 'Q1510781',
#   'Ermine Street': 'Q1355961',
#   'Kingdom of Brycheiniog': 'Q954585',
#   'Kingdom of Dyfed': 'Q956451',
#   'Kingdom of Ceredigion': 'Q2578706',
#   'Brittany': 'Q327',
#   'province of Brittany': 'Q18415117'},
#  {'North Atlantic Ocean': 'Q350134',
#   'World Ocean': 'Q715269',
#   'Sweden': 'Q34',
#   'Finland': 'Q33',
#   'Russia': 'Q159',
#   'Estonia': 'Q191',
#   'Latvia': 'Q211',
#   'Lithuania': 'Q37',
#   'Poland': 'Q36',
#   'Germany': 'Q183',
#   'Denmark': 'Q35',
#   'mediterranean sea': 'Q986177',
#   'marginal sea': 'Q204894',
#   'inland sea': 'Q2578218',
#   'Bothnian Bay': 'Q13234218',
#   'Gulf of Finland': 'Q14686',
#   'Gulf of Riga': 'Q174731',
#   'Gdańsk Bay': 'Q213367',
#   'Præstø Fjord': 'Q23741615',
#   'Great Belt': 'Q204715',
#   'Little Belt': 'Q211008',
#   'Langelandsbælt': 'Q1804948',
#   'Fehmarn Belt': 'Q506241',
#   'Baltic Proper': 'Q4852717',
#   'Bothnian Sea': 'Q1649939',
#   'Sea of Åland': 'Q271043',
#   'Archipelago Sea': 'Q650654'},
#  {'female given name': 'Q11879590', 'Josefa': 'Q6280302'},
#  {'Tunisia': 'Q948', 'governorate of Tunisia': 'Q690084'},
#  {'subculture': 'Q264965',
#   'chav': 'Q1432214',
#   'association football kit': 'Q1381731'},
#  {'Neu Wulmstorf': 'Q508054',
#   'Hamburg': 'Q1055',
#   'Rosengarten': 'Q501683',
#   'Lower Saxony': 'Q1197',
#   'Schwarze Berge': 'Q20965568',
#   'Heimfeld': 'Q3500',
#   'Germany': 'Q183',
#   'mountain range': 'Q46831',
#   'hill': 'Q54050'},
#  {'Dallas County': 'Q111168',
#   'Collin County': 'Q111174',
#   'Denton County': 'Q109265',
#   'Rockwall County': 'Q111391',
#   'Kaufman County': 'Q110486',
#   'Dallas-Fort Worth metroplex': 'Q179295',
#   'United States of America': 'Q30',
#   'city in the United States': 'Q1093829',
#   'big city': 'Q1549591',
#   'Dallas': 'Q1003667'},
#  {'Julian calendar': 'Q11184',
#   'Gregorian calendar': 'Q12138',
#   'Swedish calendar': 'Q1130275',
#   'calendar month': 'Q47018901',
#   'March 1': 'Q2393',
#   'March 2': 'Q2390',
#   'March 3': 'Q2391',
#   'March 4': 'Q2396',
#   'March 5': 'Q2392',
#   'March 6': 'Q2399',
#   'March 7': 'Q2394',
#   'March 8': 'Q2395',
#   'March 9': 'Q2401',
#   'March 10': 'Q2397',
#   'March 11': 'Q2398',
#   'March 12': 'Q2402',
#   'March 13': 'Q2400',
#   'March 14': 'Q2404',
#   'March 15': 'Q2403',
#   'March 16': 'Q2417',
#   'March 17': 'Q2419',
#   'March 18': 'Q2422',
#   'March 19': 'Q2424',
#   'March 20': 'Q2427',
#   'March 21': 'Q2433',
#   'March 22': 'Q2435',
#   'March 23': 'Q2445',
#   'March 24': 'Q2453',
#   'March 25': 'Q2454',
#   'March 26': 'Q2456',
#   'March 27': 'Q2457',
#   'March 28': 'Q2458',
#   'March 29': 'Q2459',
#   'March 30': 'Q2460',
#   'March 31': 'Q2461',
#   'month of the Gregorian calendar': 'Q18602249',
#   'February': 'Q109',
#   'April': 'Q118',
#   'Marzec': 'Q11770956',
#   'März': 'Q257002'},
#  {'human': 'Q5',
#   'politician': 'Q82955',
#   'federal deputy of Sergipe': 'Q59401962',
#   'governor of Sergipe': 'Q18176446',
#   'vice governor of Sergipe': 'Q59390655'},
#  {'Nigeria': 'Q1033',
#   'obsolete currency': 'Q28783456',
#   'historical pound': 'Q63117399'},
#  {'aspect of history': 'Q17524420'},
#  {'France': 'Q142',
#   'Switzerland': 'Q39',
#   'Canada': 'Q16',
#   'Benin': 'Q962',
#   'Burkina Faso': 'Q965',
#   'Republic of the Congo': 'Q971',
#   'Democratic Republic of the Congo': 'Q974',
#   'Ivory Coast': 'Q1008',
#   'Gabon': 'Q1000',
#   'Guinea': 'Q1006',
#   'Mali': 'Q912',
#   'Monaco': 'Q235',
#   'Niger': 'Q1032',
#   'Senegal': 'Q1041',
#   'Togo': 'Q945',
#   'Burundi': 'Q967',
#   'Cameroon': 'Q1009',
#   'Central African Republic': 'Q929',
#   'Comoros': 'Q970',
#   'Djibouti': 'Q977',
#   'Equatorial Guinea': 'Q983',
#   'Haiti': 'Q790',
#   'Luxembourg': 'Q32',
#   'Madagascar': 'Q1019',
#   'Rwanda': 'Q1037',
#   'Seychelles': 'Q1042',
#   'Chad': 'Q657',
#   'Vanuatu': 'Q686',
#   'Algeria': 'Q262',
#   'Andorra': 'Q228',
#   'Cambodia': 'Q424',
#   'Bailiwick of Guernsey': 'Q25230',
#   'India': 'Q668',
#   'Italy': 'Q38',
#   'Jersey': 'Q785',
#   'Lebanon': 'Q822',
#   'Mauritania': 'Q1025',
#   'Mauritius': 'Q1027',
#   'Morocco': 'Q1028',
#   'Vietnam': 'Q881',
#   'Belgium': 'Q31',
#   'Overseas France': 'Q203396',
#   'Tunisia': 'Q948',
#   'Laos': 'Q819',
#   'United States of America': 'Q30',
#   'modern language': 'Q1288568',
#   'natural language': 'Q33742',
#   'language': 'Q34770',
#   'Oïl': 'Q37351',
#   'Southern European language': 'Q85380120',
#   'Gallo-Romance': 'Q500394',
#   'Romance languages': 'Q19814',
#   'Classical French': 'Q3100376',
#   'French': 'Q121842',
#   'Französisch': 'Q70378541',
#   'Fransk': 'Q348443',
#   'French studies': 'Q1450761',
#   'Romance studies': 'Q1277348',
#   'フランス語学': 'Q11333703'}]

# %%
for i in range(len(prompts)):
    if len(mapping_dics[i]) == 0:
        print(f"Empty mapping dict for index {i}")
        continue

# %%
responses = query_openai_model_batch(prompts)
# Out:
# Processing prompts:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing prompts: 100%|██████████| 100/100 [01:52<00:00,  1.12s/it]

# %%
responses = query_openai_model_batch(prompts_list)
# Out:
# Processing prompts: 100%|██████████| 100/100 [02:26<00:00,  1.47s/it]

# %%
print(prompts_list[95])
# Out:
# Given the following question and a valid answer, identify all suitable candidates from the provided options that can also serve as valid answers to the question. Note that there may be multiple correct answers. Only select options that provide a direct answer to the question and adequately satisfy the information sought.
#
# Question:
# What is the name day associated with the first name of Wilhelm Oskar Ernst Windisch?
#
# Valid Answer:
# March
#
# Options:
# ['Julian calendar', 'Gregorian calendar', 'Swedish calendar', 'calendar month', 'March 1', 'March 2', 'March 3', 'March 4', 'March 5', 'March 6', 'March 7', 'March 8', 'March 9', 'March 10', 'March 11', 'March 12', 'March 13', 'March 14', 'March 15', 'March 16', 'March 17', 'March 18', 'March 19', 'March 20', 'March 21', 'March 22', 'March 23', 'March 24', 'March 25', 'March 26', 'March 27', 'March 28', 'March 29', 'March 30', 'March 31', 'month of the Gregorian calendar', 'February', 'April', 'Marzec', 'März']
#
# Respond with a JSON object containing a list of the selected options under the key 'answer'. If no suitable options are present, return an empty list.

# %%
responses
# Out:
# {1: ('{\n  "answer": [\n    "composer"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=145, total_tokens=158)),
#  3: ('{\n  "answer": [\n    "Italy",\n    "geography of Europe"\n  ]\n}',
#   CompletionUsage(completion_tokens=20, prompt_tokens=152, total_tokens=172)),
#  0: ('{\n  "answer": [\n    "secretary of state",\n    "Secretary of State"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=167, total_tokens=189)),
#  2: ('{\n  "answer": [\n    "musical work",\n    "composition",\n    "musical work/composition",\n    "music composition"\n  ]\n}',
#   CompletionUsage(completion_tokens=32, prompt_tokens=180, total_tokens=212)),
#  6: ('{\n  "answer": [\n    "As-Salam al-Malaki"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=158, total_tokens=177)),
#  5: ('{\n  "answer": [\n    "secretary of state",\n    "Secretary of State"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=166, total_tokens=188)),
#  7: ('{\n  "answer": [\n    "Uusimaa",\n    "Finland",\n    "Helsinki",\n    "Helsinki sub-region",\n    "Helsinki metropolitan area",\n    "Helsinki capital region"\n  ]\n}',
#   CompletionUsage(completion_tokens=47, prompt_tokens=244, total_tokens=291)),
#  9: ('{\n  "answer": [\n    "Cascia",\n    "Italy",\n    "frazione"\n  ]\n}',
#   CompletionUsage(completion_tokens=24, prompt_tokens=152, total_tokens=176)),
#  10: ('{\n  "answer": [\n    "Andrew and variants",\n    "Andrew"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=152, total_tokens=171)),
#  8: ('{\n  "answer": [\n    "religious occupation",\n    "cleric",\n    "minister",\n    "monk",\n    "presbyter",\n    "Christian minister",\n    "priestess",\n    "Reverend",\n    "Catholic priest",\n    "Latin Catholic priest"\n  ]\n}',
#   CompletionUsage(completion_tokens=63, prompt_tokens=177, total_tokens=240)),
#  11: ('{\n  "answer": [\n    "medicine",\n    "pharmacy",\n    "trauma surgery"\n  ]\n}',
#   CompletionUsage(completion_tokens=24, prompt_tokens=172, total_tokens=196)),
#  13: ('{\n  "answer": [\n    "Marathonas Municipality",\n    "Commune of Marathon",\n    "Greece",\n    "town"\n  ]\n}',
#   CompletionUsage(completion_tokens=33, prompt_tokens=151, total_tokens=184)),
#  15: ('{\n  "answer": [\n    "Europe",\n    "Europa",\n    "European Union",\n    "continent"\n  ]\n}',
#   CompletionUsage(completion_tokens=27, prompt_tokens=234, total_tokens=261)),
#  14: ('{\n  "answer": [\n    "Essex County",\n    "Massachusetts House of Representatives\' 12th Essex district",\n    "Massachusetts House of Representatives\' 13th Essex district",\n    "Massachusetts Senate\'s Second Essex district",\n    "United States of America",\n    "city in the United States"\n  ]\n}',
#   CompletionUsage(completion_tokens=68, prompt_tokens=192, total_tokens=260)),
#  4: ('{\n  "answer": [\n    "Zürich District",\n    "Greater Zurich Area",\n    "Zurich metropolitan area",\n    "Canton of Zürich",\n    "Kreis 1",\n    "District 2",\n    "Kreis 3",\n    "Kreis 4",\n    "Kreis 5",\n    "District 6",\n    "District 7",\n    "Kreis 8",\n    "District 9",\n    "District 10",\n    "District 11",\n    "Kreis 12",\n    "city of Switzerland",\n    "cantonal capital of Switzerland",\n    "capital city",\n    "largest city",\n    "big city",\n    "Zurich"\n  ]\n}',
#   CompletionUsage(completion_tokens=159, prompt_tokens=325, total_tokens=484)),
#  16: ('{\n  "answer": [\n    "Boyer-Ahmad County",\n    "Iran"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=159, total_tokens=181)),
#  12: ('{\n  "answer": [\n    "Eurasia",\n    "Earth",\n    "Northern Hemisphere",\n    "Northern Europe",\n    "Northeastern Europe",\n    "Southern Europe",\n    "Southeast Europe",\n    "Eastern Europe",\n    "Western Europe",\n    "Central Europe",\n    "Southwestern Europe",\n    "Northwestern Europe",\n    "Europa",\n    "Europe",\n    "European Union",\n    "continent",\n    "geographic region"\n  ]\n}',
#   CompletionUsage(completion_tokens=98, prompt_tokens=236, total_tokens=334)),
#  20: ('{\n  "answer": [\n    "biologist"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=137, total_tokens=151)),
#  19: ('{\n  "answer": [\n    "Brendan"\n  ]\n}',
#   CompletionUsage(completion_tokens=15, prompt_tokens=150, total_tokens=165)),
#  22: ('{\n  "answer": [\n    "central bank"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=144, total_tokens=158)),
#  21: ('{\n  "answer": [\n    "United States of America"\n  ]\n}',
#   CompletionUsage(completion_tokens=16, prompt_tokens=152, total_tokens=168)),
#  23: ('{\n  "answer": [\n    "Accipitridae"\n  ]\n}',
#   CompletionUsage(completion_tokens=17, prompt_tokens=151, total_tokens=168)),
#  24: ('{\n  "answer": [\n    "Bill"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=150, total_tokens=163)),
#  27: ('{\n  "answer": [\n    "class of award"\n  ]\n}',
#   CompletionUsage(completion_tokens=15, prompt_tokens=152, total_tokens=167)),
#  18: ('{\n  "answer": [\n    "Connacht Irish",\n    "Munster Irish",\n    "Ulster Irish",\n    "Goidelic"\n  ]\n}',
#   CompletionUsage(completion_tokens=34, prompt_tokens=179, total_tokens=213)),
#  25: ('{\n  "answer": [\n    "Harry S. Truman",\n    "politician",\n    "President of the United States",\n    "Vice President of the United States",\n    "United States senator",\n    "military officer"\n  ]\n}',
#   CompletionUsage(completion_tokens=51, prompt_tokens=236, total_tokens=287)),
#  29: ('{\n  "answer": [\n    "Josefa"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=136, total_tokens=150)),
#  26: ('{\n  "answer": [\n    "Cyrillic-script alphabet",\n    "Cyrillic script"\n  ]\n}',
#   CompletionUsage(completion_tokens=26, prompt_tokens=257, total_tokens=283)),
#  28: ('{\n  "answer": [\n    "Accipitridae"\n  ]\n}',
#   CompletionUsage(completion_tokens=17, prompt_tokens=154, total_tokens=171)),
#  17: ('{\n  "answer": [\n    "Province of Rome",\n    "Papal States",\n    "Ancient Rome",\n    "Roman Republic",\n    "Roman Empire",\n    "Western Roman Empire",\n    "Metropolitan City of Rome",\n    "Italy",\n    "Kingdom of Italy",\n    "Ostrogothic Kingdom",\n    "Byzantine Empire",\n    "Roman Kingdom",\n    "Vatican City",\n    "capital city",\n    "metropolis",\n    "largest city",\n    "commune of Italy",\n    "Rzym"\n  ]\n}',
#   CompletionUsage(completion_tokens=117, prompt_tokens=374, total_tokens=491)),
#  32: ('{\n  "answer": [\n    "history of a city"\n  ]\n}',
#   CompletionUsage(completion_tokens=16, prompt_tokens=146, total_tokens=162)),
#  31: ('{\n  "answer": [\n    "historical country",\n    "Angkor 333"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=156, total_tokens=178)),
#  30: ('{\n  "answer": [\n    "Argentina"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=146, total_tokens=159)),
#  33: ('{\n  "answer": [\n    "Alameda County",\n    "county seat",\n    "Oakland"\n  ]\n}',
#   CompletionUsage(completion_tokens=25, prompt_tokens=174, total_tokens=199)),
#  36: ('{\n  "answer": [\n    "Roman Empire",\n    "Ancient Rome",\n    "Roman province"\n  ]\n}',
#   CompletionUsage(completion_tokens=25, prompt_tokens=207, total_tokens=232)),
#  34: ('{\n  "answer": [\n    "electrical grid",\n    "ground wire",\n    "power cable",\n    "high-voltage power line",\n    "industrial building",\n    "electrical cable"\n  ]\n}',
#   CompletionUsage(completion_tokens=45, prompt_tokens=183, total_tokens=228)),
#  35: ('{\n  "answer": [\n    "convex cyclic quadrilateral",\n    "equiangular polygon",\n    "hyperrectangle",\n    "parallelogram"\n  ]\n}',
#   CompletionUsage(completion_tokens=35, prompt_tokens=188, total_tokens=223)),
#  39: ('{\n  "answer": [\n    "royal coat of arms of the United Kingdom"\n  ]\n}',
#   CompletionUsage(completion_tokens=21, prompt_tokens=169, total_tokens=190)),
#  40: ('{\n  "answer": [\n    "United Kingdom of Great Britain and Ireland",\n    "Parliament of Great Britain"\n  ]\n}',
#   CompletionUsage(completion_tokens=27, prompt_tokens=198, total_tokens=225)),
#  43: ('{\n  "answer": [\n    "taxonomic rank"\n  ]\n}',
#   CompletionUsage(completion_tokens=15, prompt_tokens=173, total_tokens=188)),
#  37: ('{\n  "answer": [\n    "sports competition",\n    "sport",\n    "sports discipline",\n    "سباق"\n  ]\n}',
#   CompletionUsage(completion_tokens=30, prompt_tokens=165, total_tokens=195)),
#  41: ('{\n  "answer": [\n    "Latin-script alphabet",\n    "Latin script"\n  ]\n}',
#   CompletionUsage(completion_tokens=20, prompt_tokens=220, total_tokens=240)),
#  42: ('{\n  "answer": [\n    "United Kingdom"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=143, total_tokens=157)),
#  44: ('{\n  "answer": [\n    "India",\n    "state of India"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=182, total_tokens=201)),
#  47: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=138, total_tokens=145)),
#  45: ('{\n  "answer": [\n    "Lenny"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=150, total_tokens=164)),
#  46: ('{\n  "answer": [\n    "Allan"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=139, total_tokens=153)),
#  50: ('{\n  "answer": [\n    "Earth"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=313, total_tokens=326)),
#  49: ('{\n  "answer": [\n    "municipal flag"\n  ]\n}',
#   CompletionUsage(completion_tokens=16, prompt_tokens=146, total_tokens=162)),
#  48: ('{\n  "answer": [\n    "time zone named for a UTC offset"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=147, total_tokens=166)),
#  54: ('{\n  "answer": [\n    "family"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=181, total_tokens=194)),
#  52: ('{\n  "answer": [\n    "aspect of history",\n    "study of history"\n  ]\n}',
#   CompletionUsage(completion_tokens=21, prompt_tokens=144, total_tokens=165)),
#  51: ('{\n  "answer": [\n    "female bisexuality",\n    "male bisexuality",\n    "non-binary bisexual"\n  ]\n}',
#   CompletionUsage(completion_tokens=29, prompt_tokens=217, total_tokens=246)),
#  38: ('{\n  "answer": [\n    "Independence Award in Independence and Liberation War",\n    "Independence Award in Science and Technology",\n    "Independence Award in Medicine",\n    "Independence Award in Education",\n    "Independence Award in Literature",\n    "Independence Award in Culture",\n    "Independence Award in Sports",\n    "Independence Award in Rural Development",\n    "Independence Award in Social Services",\n    "Independence Award in Population Control",\n    "Independence Award in Public Administration",\n    "Independence Award in Research and Training",\n    "Independence Award in Language and Independence Movement",\n    "Independence Award in Economics",\n    "Independence Award in Food Security"\n  ]\n}',
#   CompletionUsage(completion_tokens=144, prompt_tokens=280, total_tokens=424)),
#  53: ('{\n  "answer": [\n    "politician",\n    "Voivodeship marshal",\n    "member of the Sejm of the Republic of Poland",\n    "member of the European Parliament"\n  ]\n}',
#   CompletionUsage(completion_tokens=43, prompt_tokens=178, total_tokens=221)),
#  57: ('{\n  "answer": [\n    "Accipitridae"\n  ]\n}',
#   CompletionUsage(completion_tokens=17, prompt_tokens=154, total_tokens=171)),
#  55: ('{\n  "answer": [\n    "secretary of state",\n    "Secretary of State"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=164, total_tokens=186)),
#  56: ('{\n  "answer": [\n    "politician",\n    "mayor of Bergamo"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=174, total_tokens=196)),
#  62: ('{\n  "answer": [\n    "Patrick"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=148, total_tokens=161)),
#  58: ('{\n  "answer": [\n    "superorder",\n    "class"\n  ]\n}',
#   CompletionUsage(completion_tokens=18, prompt_tokens=169, total_tokens=187)),
#  60: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=207, total_tokens=214)),
#  61: ('{\n  "answer": [\n    "politician",\n    "lawyer",\n    "Mississippi state representative",\n    "Member of the Mississippi Senate",\n    "Governor of Mississippi",\n    "United States senator"\n  ]\n}',
#   CompletionUsage(completion_tokens=47, prompt_tokens=174, total_tokens=221)),
#  63: ('{\n  "answer": [\n    "astrophysics",\n    "physics",\n    "cosmogony"\n  ]\n}',
#   CompletionUsage(completion_tokens=26, prompt_tokens=160, total_tokens=186)),
#  64: ('{\n  "answer": [\n    "deputy of the Legislative Assembly of the Federal District",\n    "Asamblea de Representantes del Distrito Federal",\n    "Congrès de la Ville de Mexico"\n  ]\n}',
#   CompletionUsage(completion_tokens=46, prompt_tokens=196, total_tokens=242)),
#  65: ('{\n  "answer": [\n    "mountain range"\n  ]\n}',
#   CompletionUsage(completion_tokens=15, prompt_tokens=151, total_tokens=166)),
#  66: ('{\n  "answer": [\n    "Texas",\n    "San Angelo",\n    "United States of America",\n    "county of Texas"\n  ]\n}',
#   CompletionUsage(completion_tokens=31, prompt_tokens=154, total_tokens=185)),
#  69: ('{\n  "answer": [\n    "U.S. Agency for Global Media"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=194, total_tokens=213)),
#  71: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=146, total_tokens=153)),
#  70: ('{\n  "answer": [\n    "Daïra of Constantine",\n    "Constantina"\n  ]\n}',
#   CompletionUsage(completion_tokens=23, prompt_tokens=169, total_tokens=192)),
#  72: ('{\n  "answer": [\n    "Washington",\n    "Colfax",\n    "United States of America"\n  ]\n}',
#   CompletionUsage(completion_tokens=25, prompt_tokens=163, total_tokens=188)),
#  74: ('{\n  "answer": [\n    "Latin-script alphabet",\n    "Latin script"\n  ]\n}',
#   CompletionUsage(completion_tokens=20, prompt_tokens=219, total_tokens=239)),
#  68: ('{\n  "answer": [\n    "Southern Hemisphere",\n    "Southern Africa",\n    "Antarctica",\n    "Australia",\n    "South America",\n    "Insular Oceania",\n    "South Atlantic Ocean",\n    "Indian Ocean",\n    "Pacific Ocean",\n    "South Pacific Ocean",\n    "Southern Indian Ocean",\n    "Global South",\n    "Southern Celestial Hemisphere"\n  ]\n}',
#   CompletionUsage(completion_tokens=82, prompt_tokens=201, total_tokens=283)),
#  76: ('{\n  "answer": [\n    "martial arts film",\n    "Shaolin vs. Wu-Tang"\n  ]\n}',
#   CompletionUsage(completion_tokens=26, prompt_tokens=162, total_tokens=188)),
#  75: ('{\n  "answer": [\n    "audiovisual work",\n    "moving image",\n    "film reel",\n    "film theory",\n    "film studies",\n    "sociology of film"\n  ]\n}',
#   CompletionUsage(completion_tokens=43, prompt_tokens=188, total_tokens=231)),
#  59: ('{\n  "answer": [\n    "August 1",\n    "August 2",\n    "August 3",\n    "August 4",\n    "August 5",\n    "August 6",\n    "August 7",\n    "August 8",\n    "August 9",\n    "August 10",\n    "August 11",\n    "August 12",\n    "August 13",\n    "August 14",\n    "August 15",\n    "August 16",\n    "August 17",\n    "August 18",\n    "August 19",\n    "August 20",\n    "August 21",\n    "August 22",\n    "August 23",\n    "August 24",\n    "August 25",\n    "August 26",\n    "August 27",\n    "August 28",\n    "August 29",\n    "August 30",\n    "August 31",\n    "Sierpień",\n    "August"\n  ]\n}',
#   CompletionUsage(completion_tokens=206, prompt_tokens=333, total_tokens=539)),
#  78: ('{\n  "answer": [\n    "Denali"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=171, total_tokens=185)),
#  79: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=143, total_tokens=150)),
#  80: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=157, total_tokens=164)),
#  77: ('{\n  "answer": [\n    "Antigua and Barbuda"\n  ]\n}',
#   CompletionUsage(completion_tokens=17, prompt_tokens=382, total_tokens=399)),
#  81: ('{\n  "answer": [\n    "secretary of state",\n    "Secretary of State"\n  ]\n}',
#   CompletionUsage(completion_tokens=22, prompt_tokens=166, total_tokens=188)),
#  82: ('{\n  "answer": [\n    "writer",\n    "poet",\n    "lyricist"\n  ]\n}',
#   CompletionUsage(completion_tokens=24, prompt_tokens=159, total_tokens=183)),
#  85: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=151, total_tokens=158)),
#  83: ('{\n  "answer": [\n    "Brazil",\n    "Brazilian Portuguese"\n  ]\n}',
#   CompletionUsage(completion_tokens=19, prompt_tokens=280, total_tokens=299)),
#  84: ('{\n  "answer": [\n    "aspect of history",\n    "study of history"\n  ]\n}',
#   CompletionUsage(completion_tokens=21, prompt_tokens=145, total_tokens=166)),
#  87: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=142, total_tokens=149)),
#  88: ('{\n  "answer": [\n    "Roman Empire",\n    "Ancient Rome",\n    "Roman province"\n  ]\n}',
#   CompletionUsage(completion_tokens=25, prompt_tokens=202, total_tokens=227)),
#  86: ('{\n  "answer": [\n    "early childhood",\n    "adolescence",\n    "preadolescence",\n    "Childhood",\n    "sociology of childhood"\n  ]\n}',
#   CompletionUsage(completion_tokens=39, prompt_tokens=196, total_tokens=235)),
#  90: ('{\n  "answer": [\n    "Josefa"\n  ]\n}',
#   CompletionUsage(completion_tokens=14, prompt_tokens=139, total_tokens=153)),
#  91: ('{\n  "answer": [\n    "Tunisia",\n    "governorate of Tunisia"\n  ]\n}',
#   CompletionUsage(completion_tokens=23, prompt_tokens=152, total_tokens=175)),
#  92: ('{\n  "answer": [\n    "association football kit"\n  ]\n}',
#   CompletionUsage(completion_tokens=15, prompt_tokens=159, total_tokens=174)),
#  93: ('{\n  "answer": [\n    "Schwarze Berge"\n  ]\n}',
#   CompletionUsage(completion_tokens=17, prompt_tokens=184, total_tokens=201)),
#  94: ('{\n  "answer": [\n    "Dallas"\n  ]\n}',
#   CompletionUsage(completion_tokens=13, prompt_tokens=193, total_tokens=206)),
#  89: ('{\n  "answer": [\n    "Sweden",\n    "Finland",\n    "Russia",\n    "Estonia",\n    "Latvia",\n    "Lithuania",\n    "Poland",\n    "Germany",\n    "Denmark",\n    "marginal sea",\n    "Gulf of Finland",\n    "Gulf of Riga",\n    "Gdańsk Bay",\n    "Baltic Proper",\n    "Bothnian Sea",\n    "Sea of Åland",\n    "Archipelago Sea"\n  ]\n}',
#   CompletionUsage(completion_tokens=111, prompt_tokens=280, total_tokens=391)),
#  96: ('{\n  "answer": [\n    "politician",\n    "governor of Sergipe"\n  ]\n}',
#   CompletionUsage(completion_tokens=23, prompt_tokens=163, total_tokens=186)),
#  98: ('{\n  "answer": []\n}',
#   CompletionUsage(completion_tokens=7, prompt_tokens=137, total_tokens=144)),
#  97: ('{\n  "answer": [\n    "obsolete currency",\n    "historical pound"\n  ]\n}',
#   CompletionUsage(completion_tokens=20, prompt_tokens=153, total_tokens=173)),
#  99: ('{\n  "answer": [\n    "French",\n    "Französisch",\n    "Fransk",\n    "フランス語学"\n  ]\n}',
#   CompletionUsage(completion_tokens=35, prompt_tokens=415, total_tokens=450)),
#  73: ('{\n  "answer": [\n    "East Asia",\n    "Japanese archipelago",\n    "Aichi Prefecture",\n    "Akita Prefecture",\n    "Aomori Prefecture",\n    "Chiba Prefecture",\n    "Fukui Prefecture",\n    "Fukushima Prefecture",\n    "Gunma Prefecture",\n    "Hokkaido",\n    "Ibaraki Prefecture",\n    "Iwate Prefecture",\n    "Miyagi Prefecture",\n    "Saitama Prefecture",\n    "Tochigi Prefecture",\n    "Tokyo",\n    "Kanagawa Prefecture",\n    "Niigata Prefecture",\n    "Toyama Prefecture",\n    "Ishikawa Prefecture",\n    "Yamagata Prefecture",\n    "Yamanashi Prefecture",\n    "Nagano Prefecture",\n    "Gifu Prefecture",\n    "Shizuoka Prefecture",\n    "Mie Prefecture",\n    "Shiga Prefecture",\n    "Kyoto Prefecture",\n    "Osaka Prefecture",\n    "Hyōgo Prefecture",\n    "Nara Prefecture",\n    "Wakayama Prefecture",\n    "Tottori Prefecture",\n    "Shimane Prefecture",\n    "Okayama Prefecture",\n    "Hiroshima Prefecture",\n    "Yamaguchi Prefecture",\n    "Tokushima Prefecture",\n    "Kagawa Prefecture",\n    "Ehime Prefecture",\n    "Kōchi Prefecture",\n    "Fukuoka Prefecture",\n    "Nagasaki Prefecture",\n    "Kumamoto Prefecture",\n    "Oita Prefecture",\n    "Miyazaki Prefecture",\n    "Kagoshima Prefecture",\n    "Okinawa Prefecture",\n    "Saga Prefecture",\n    "Japan",\n    "sovereign state",\n    "island country",\n    "country",\n    "Northern Japan",\n    "Eastern Japan",\n    "Central Japan",\n    "Western Japan",\n    "Southern Japan"\n  ]\n}',
#   CompletionUsage(completion_tokens=431, prompt_tokens=833, total_tokens=1264)),
#  95: ('{\n  "answer": [\n    "March 1",\n    "March 2",\n    "March 3",\n    "March 4",\n    "March 5",\n    "March 6",\n    "March 7",\n    "March 8",\n    "March 9",\n    "March 10",\n    "March 11",\n    "March 12",\n    "March 13",\n    "March 14",\n    "March 15",\n    "March 16",\n    "March 17",\n    "March 18",\n    "March 19",\n    "March 20",\n    "March 21",\n    "March 22",\n    "March 23",\n    "March 24",\n    "March 25",\n    "March 26",\n    "March 27",\n    "March 28",\n    "March 29",\n    "March 30",\n    "March 31",\n    "Marzec",\n    "März"\n  ]\n}',
#   CompletionUsage(completion_tokens=207, prompt_tokens=329, total_tokens=536)),
#  67: ('{\n  "answer": [\n    "University of Padua School of Medicine and Surgery",\n    "Biblioteca medica Vincenzo Pinali. Sezione moderna. Università degli studi di Padova",\n    "Biblioteca della sede di Bressanone. Università degli studi di Padova",\n    "Biblioteca del Centro di cinematografia scientifica ed audiovisivi. Università degli studi di Padova",\n    "Biblioteca del Centro internazionale di idrologia della Facoltà di ingegneria. Università degli studi di Padova",\n    "Biblioteca centrale di Giurisprudenza. Sezione di diritto privato e critica del diritto. Università degli studi di Padova",\n    "Biblioteca centrale di giurisprudenza. Sezione di diritto pubblico internazionale e comunitario. Università degli studi di Padova",\n    "Biblioteca centrale di Agripolis Pietro Arduino. Università degli studi di Padova",\n    "Biblioteca della Presidenza. Facoltà di giurisprudenza. Università degli studi di Padova",\n    "Biblioteca di diritto romano. Università degli studi di Padova",\n    "Biblioteca centrale di ingegneria. Università degli studi di Padova",\n    "Biblioteca di scienze economiche e aziendali. Università degli studi di Padova",\n    "Biblioteca di filosofia del diritto. Università degli studi di Padova",\n    "Biblioteca dell\'Istituto di storia della medicina della Facoltà di medicina e chirurgia. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Sezione di geofisica. Università degli studi di Padova",\n    "Biblioteca di filosofia. Università degli studi di Padova",\n    "Biblioteca dell\'Istituto di storia del teatro e dello spettacolo della Facoltà di scienze della formazione. Università degli studi di Padova",\n    "Biblioteca di scienze politiche Ettore Anchieri. Università degli studi di Padova",\n    "Biblioteca di Scienze Statistiche \\"Bernardo Colombo\\". Università degli studi di Padova",\n    "Biblioteca di matematica. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Università degli studi di Padova",\n    "Biblioteca di fisica e astronomia. Sede di fisica. Università degli studi di Padova",\n    "Biblioteca di geografia. Università degli studi di Padova",\n    "Biblioteca biologico-medica Vallisneri. Università degli studi di Padova",\n    "Biblioteca di Scienze del farmaco. Università degli studi di Padova",\n    "Biblioteca di storia. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di mineralogia e petrologia. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di metodi e modelli matematici per le scienze applicate. Università degli studi di Padova",\n    "Biblioteca centrale di psicologia Fabio Metelli. Università degli studi di Padova",\n    "Biblioteca di Chimica Cesare Pecile. Università degli studi di Padova",\n    "Biblioteca del farmaco. Università degli studi di Padova",\n    "Biblioteca medica Vincenzo Pinali. Sezione antica della Facoltà di medicina e chirurgia. Università degli studi di Padova",\n    "Biblioteca dell\'Orto botanico. Università degli studi di Padova",\n    "Biblioteca di Scienze dell\'Antichità Arte Musica Liviano. Università degli studi di Padova",\n    "Biblioteca di neuroscienze. Università degli studi di Padova",\n    "Biblioteca centrale di ingegneria. Sede di ingegneria dell\'informazione e ingegneria elettrica \\"Giovanni Someda\\". Università degli studi di Padova",\n    "Biblioteca di diritto comparato Ruggero Meneghelli. Università degli studi di Padova",\n    "Biblioteca medica Vincenzo Pinali. Sezione antica. Università degli studi di Padova",\n    "Biblioteca di storia. Università. Università degli studi di Padova",\n    "Biblioteca di fisica e astronomia . Sede di astronomia. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione internazionale. Università degli studi di Padova",\n    "Biblioteca del Dipartimento di d ...
#   CompletionUsage(completion_tokens=1466, prompt_tokens=1659, total_tokens=3125))}

# %%
abstract_valid_answers = {}
for i in range(len(responses)):
    response = responses[i][0]
    mapping_dict = mapping_dics[i]
    response = json.loads(response)
    abstract_valid_answers[i] = response['answer']

# %%
abstract_valid_answers
# Out:
# {0: ['secretary of state', 'Secretary of State'],
#  1: ['composer'],
#  2: ['musical work',
#   'composition',
#   'musical work/composition',
#   'music composition'],
#  3: ['Italy', 'geography of Europe'],
#  4: ['Zürich District',
#   'Greater Zurich Area',
#   'Zurich metropolitan area',
#   'Canton of Zürich',
#   'Kreis 1',
#   'District 2',
#   'Kreis 3',
#   'Kreis 4',
#   'Kreis 5',
#   'District 6',
#   'District 7',
#   'Kreis 8',
#   'District 9',
#   'District 10',
#   'District 11',
#   'Kreis 12',
#   'city of Switzerland',
#   'cantonal capital of Switzerland',
#   'capital city',
#   'largest city',
#   'big city',
#   'Zurich'],
#  5: ['secretary of state', 'Secretary of State'],
#  6: ['As-Salam al-Malaki'],
#  7: ['Uusimaa',
#   'Finland',
#   'Helsinki',
#   'Helsinki sub-region',
#   'Helsinki metropolitan area',
#   'Helsinki capital region'],
#  8: ['religious occupation',
#   'cleric',
#   'minister',
#   'monk',
#   'presbyter',
#   'Christian minister',
#   'priestess',
#   'Reverend',
#   'Catholic priest',
#   'Latin Catholic priest'],
#  9: ['Cascia', 'Italy', 'frazione'],
#  10: ['Andrew and variants', 'Andrew'],
#  11: ['medicine', 'pharmacy', 'trauma surgery'],
#  12: ['Eurasia',
#   'Earth',
#   'Northern Hemisphere',
#   'Northern Europe',
#   'Northeastern Europe',
#   'Southern Europe',
#   'Southeast Europe',
#   'Eastern Europe',
#   'Western Europe',
#   'Central Europe',
#   'Southwestern Europe',
#   'Northwestern Europe',
#   'Europa',
#   'Europe',
#   'European Union',
#   'continent',
#   'geographic region'],
#  13: ['Marathonas Municipality', 'Commune of Marathon', 'Greece', 'town'],
#  14: ['Essex County',
#   "Massachusetts House of Representatives' 12th Essex district",
#   "Massachusetts House of Representatives' 13th Essex district",
#   "Massachusetts Senate's Second Essex district",
#   'United States of America',
#   'city in the United States'],
#  15: ['Europe', 'Europa', 'European Union', 'continent'],
#  16: ['Boyer-Ahmad County', 'Iran'],
#  17: ['Province of Rome',
#   'Papal States',
#   'Ancient Rome',
#   'Roman Republic',
#   'Roman Empire',
#   'Western Roman Empire',
#   'Metropolitan City of Rome',
#   'Italy',
#   'Kingdom of Italy',
#   'Ostrogothic Kingdom',
#   'Byzantine Empire',
#   'Roman Kingdom',
#   'Vatican City',
#   'capital city',
#   'metropolis',
#   'largest city',
#   'commune of Italy',
#   'Rzym'],
#  18: ['Connacht Irish', 'Munster Irish', 'Ulster Irish', 'Goidelic'],
#  19: ['Brendan'],
#  20: ['biologist'],
#  21: ['United States of America'],
#  22: ['central bank'],
#  23: ['Accipitridae'],
#  24: ['Bill'],
#  25: ['Harry S. Truman',
#   'politician',
#   'President of the United States',
#   'Vice President of the United States',
#   'United States senator',
#   'military officer'],
#  26: ['Cyrillic-script alphabet', 'Cyrillic script'],
#  27: ['class of award'],
#  28: ['Accipitridae'],
#  29: ['Josefa'],
#  30: ['Argentina'],
#  31: ['historical country', 'Angkor 333'],
#  32: ['history of a city'],
#  33: ['Alameda County', 'county seat', 'Oakland'],
#  34: ['electrical grid',
#   'ground wire',
#   'power cable',
#   'high-voltage power line',
#   'industrial building',
#   'electrical cable'],
#  35: ['convex cyclic quadrilateral',
#   'equiangular polygon',
#   'hyperrectangle',
#   'parallelogram'],
#  36: ['Roman Empire', 'Ancient Rome', 'Roman province'],
#  37: ['sports competition', 'sport', 'sports discipline', 'سباق'],
#  38: ['Independence Award in Independence and Liberation War',
#   'Independence Award in Science and Technology',
#   'Independence Award in Medicine',
#   'Independence Award in Education',
#   'Independence Award in Literature',
#   'Independence Award in Culture',
#   'Independence Award in Sports',
#   'Independence Award in Rural Development',
#   'Independence Award in Social Services',
#   'Independence Award in Population Control',
#   'Independence Award in Public Administration',
#   'Independence Award in Research and Training',
#   'Independence Award in Language and Independence Movement',
#   'Independence Award in Economics',
#   'Independence Award in Food Security'],
#  39: ['royal coat of arms of the United Kingdom'],
#  40: ['United Kingdom of Great Britain and Ireland',
#   'Parliament of Great Britain'],
#  41: ['Latin-script alphabet', 'Latin script'],
#  42: ['United Kingdom'],
#  43: ['taxonomic rank'],
#  44: ['India', 'state of India'],
#  45: ['Lenny'],
#  46: ['Allan'],
#  47: [],
#  48: ['time zone named for a UTC offset'],
#  49: ['municipal flag'],
#  50: ['Earth'],
#  51: ['female bisexuality', 'male bisexuality', 'non-binary bisexual'],
#  52: ['aspect of history', 'study of history'],
#  53: ['politician',
#   'Voivodeship marshal',
#   'member of the Sejm of the Republic of Poland',
#   'member of the European Parliament'],
#  54: ['family'],
#  55: ['secretary of state', 'Secretary of State'],
#  56: ['politician', 'mayor of Bergamo'],
#  57: ['Accipitridae'],
#  58: ['superorder', 'class'],
#  59: ['August 1',
#   'August 2',
#   'August 3',
#   'August 4',
#   'August 5',
#   'August 6',
#   'August 7',
#   'August 8',
#   'August 9',
#   'August 10',
#   'August 11',
#   'August 12',
#   'August 13',
#   'August 14',
#   'August 15',
#   'August 16',
#   'August 17',
#   'August 18',
#   'August 19',
#   'August 20',
#   'August 21',
#   'August 22',
#   'August 23',
#   'August 24',
#   'August 25',
#   'August 26',
#   'August 27',
#   'August 28',
#   'August 29',
#   'August 30',
#   'August 31',
#   'Sierpień',
#   'August'],
#  60: [],
#  61: ['politician',
#   'lawyer',
#   'Mississippi state representative',
#   'Member of the Mississippi Senate',
#   'Governor of Mississippi',
#   'United States senator'],
#  62: ['Patrick'],
#  63: ['astrophysics', 'physics', 'cosmogony'],
#  64: ['deputy of the Legislative Assembly of the Federal District',
#   'Asamblea de Representantes del Distrito Federal',
#   'Congrès de la Ville de Mexico'],
#  65: ['mountain range'],
#  66: ['Texas', 'San Angelo', 'United States of America', 'county of Texas'],
#  67: ['University of Padua School of Medicine and Surgery',
#   'Biblioteca medica Vincenzo Pinali. Sezione moderna. Università degli studi di Padova',
#   'Biblioteca della sede di Bressanone. Università degli studi di Padova',
#   'Biblioteca del Centro di cinematografia scientifica ed audiovisivi. Università degli studi di Padova',
#   'Biblioteca del Centro internazionale di idrologia della Facoltà di ingegneria. Università degli studi di Padova',
#   'Biblioteca centrale di Giurisprudenza. Sezione di diritto privato e critica del diritto. Università degli studi di Padova',
#   'Biblioteca centrale di giurisprudenza. Sezione di diritto pubblico internazionale e comunitario. Università degli studi di Padova',
#   'Biblioteca centrale di Agripolis Pietro Arduino. Università degli studi di Padova',
#   'Biblioteca della Presidenza. Facoltà di giurisprudenza. Università degli studi di Padova',
#   'Biblioteca di diritto romano. Università degli studi di Padova',
#   'Biblioteca centrale di ingegneria. Università degli studi di Padova',
#   'Biblioteca di scienze economiche e aziendali. Università degli studi di Padova',
#   'Biblioteca di filosofia del diritto. Università degli studi di Padova',
#   "Biblioteca dell'Istituto di storia della medicina della Facoltà di medicina e chirurgia. Università degli studi di Padova",
#   'Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Sezione di geofisica. Università degli studi di Padova',
#   'Biblioteca di filosofia. Università degli studi di Padova',
#   "Biblioteca dell'Istituto di storia del teatro e dello spettacolo della Facoltà di scienze della formazione. Università degli studi di Padova",
#   'Biblioteca di scienze politiche Ettore Anchieri. Università degli studi di Padova',
#   'Biblioteca di Scienze Statistiche "Bernardo Colombo". Università degli studi di Padova',
#   'Biblioteca di matematica. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di geologia, paleontologia e geofisica. Università degli studi di Padova',
#   'Biblioteca di fisica e astronomia. Sede di fisica. Università degli studi di Padova',
#   'Biblioteca di geografia. Università degli studi di Padova',
#   'Biblioteca biologico-medica Vallisneri. Università degli studi di Padova',
#   'Biblioteca di Scienze del farmaco. Università degli studi di Padova',
#   'Biblioteca di storia. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di mineralogia e petrologia. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di metodi e modelli matematici per le scienze applicate. Università degli studi di Padova',
#   'Biblioteca centrale di psicologia Fabio Metelli. Università degli studi di Padova',
#   'Biblioteca di Chimica Cesare Pecile. Università degli studi di Padova',
#   'Biblioteca del farmaco. Università degli studi di Padova',
#   'Biblioteca medica Vincenzo Pinali. Sezione antica della Facoltà di medicina e chirurgia. Università degli studi di Padova',
#   "Biblioteca dell'Orto botanico. Università degli studi di Padova",
#   "Biblioteca di Scienze dell'Antichità Arte Musica Liviano. Università degli studi di Padova",
#   'Biblioteca di neuroscienze. Università degli studi di Padova',
#   'Biblioteca centrale di ingegneria. Sede di ingegneria dell\'informazione e ingegneria elettrica "Giovanni Someda". Università degli studi di Padova',
#   'Biblioteca di diritto comparato Ruggero Meneghelli. Università degli studi di Padova',
#   'Biblioteca medica Vincenzo Pinali. Sezione antica. Università degli studi di Padova',
#   'Biblioteca di storia. Università. Università degli studi di Padova',
#   'Biblioteca di fisica e astronomia . Sede di astronomia. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione internazionale. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione penale. Università degli studi di Padova',
#   "Biblioteca P. Cancellieri del Centro di studi e di formazione sui diritti dell'uomo e dei popoli. Università degli studi di Padova",
#   'Mediateca del Centro Linguistico di Ateneo. Università degli studi di Padova',
#   'Biblioteca di Palazzo Maldura. Sezione Francese. Università degli studi di Padova',
#   'Biblioteca di Slavistica e Ungherese. Università degli studi di Padova (Sezione staccata della Biblioteca Maldura)',
#   'Biblioteca del Dipartimento di diritto pubblico, internazionale, e comunitario. Sezione tributario. Università degli studi di Padova',
#   'Biblioteca del Dipartimento di farmacologia ed anestesiologia E. Meneghetti. Sezione farmacologia. Università degli studi di Padova',
#   'Biblioteca di Palazzo Maldura. Sezione Sala riviste. Università degli studi di Padova',
#   'Biblioteca centrale di Ingegneria. Sede di tecnica e gestione dei sistemi industriali. Università degli studi di Padova',
#   'Biblioteca di astronomia. Osservatorio di astrofisica. Università degli studi di Padova'],
#  68: ['Southern Hemisphere',
#   'Southern Africa',
#   'Antarctica',
#   'Australia',
#   'South America',
#   'Insular Oceania',
#   'South Atlantic Ocean',
#   'Indian Ocean',
#   'Pacific Ocean',
#   'South Pacific Ocean',
#   'Southern Indian Ocean',
#   'Global South',
#   'Southern Celestial Hemisphere'],
#  69: ['U.S. Agency for Global Media'],
#  70: ['Daïra of Constantine', 'Constantina'],
#  71: [],
#  72: ['Washington', 'Colfax', 'United States of America'],
#  73: ['East Asia',
#   'Japanese archipelago',
#   'Aichi Prefecture',
#   'Akita Prefecture',
#   'Aomori Prefecture',
#   'Chiba Prefecture',
#   'Fukui Prefecture',
#   'Fukushima Prefecture',
#   'Gunma Prefecture',
#   'Hokkaido',
#   'Ibaraki Prefecture',
#   'Iwate Prefecture',
#   'Miyagi Prefecture',
#   'Saitama Prefecture',
#   'Tochigi Prefecture',
#   'Tokyo',
#   'Kanagawa Prefecture',
#   'Niigata Prefecture',
#   'Toyama Prefecture',
#   'Ishikawa Prefecture',
#   'Yamagata Prefecture',
#   'Yamanashi Prefecture',
#   'Nagano Prefecture',
#   'Gifu Prefecture',
#   'Shizuoka Prefecture',
#   'Mie Prefecture',
#   'Shiga Prefecture',
#   'Kyoto Prefecture',
#   'Osaka Prefecture',
#   'Hyōgo Prefecture',
#   'Nara Prefecture',
#   'Wakayama Prefecture',
#   'Tottori Prefecture',
#   'Shimane Prefecture',
#   'Okayama Prefecture',
#   'Hiroshima Prefecture',
#   'Yamaguchi Prefecture',
#   'Tokushima Prefecture',
#   'Kagawa Prefecture',
#   'Ehime Prefecture',
#   'Kōchi Prefecture',
#   'Fukuoka Prefecture',
#   'Nagasaki Prefecture',
#   'Kumamoto Prefecture',
#   'Oita Prefecture',
#   'Miyazaki Prefecture',
#   'Kagoshima Prefecture',
#   'Okinawa Prefecture',
#   'Saga Prefecture',
#   'Japan',
#   'sovereign state',
#   'island country',
#   'country',
#   'Northern Japan',
#   'Eastern Japan',
#   'Central Japan',
#   'Western Japan',
#   'Southern Japan'],
#  74: ['Latin-script alphabet', 'Latin script'],
#  75: ['audiovisual work',
#   'moving image',
#   'film reel',
#   'film theory',
#   'film studies',
#   'sociology of film'],
#  76: ['martial arts film', 'Shaolin vs. Wu-Tang'],
#  77: ['Antigua and Barbuda'],
#  78: ['Denali'],
#  79: [],
#  80: [],
#  81: ['secretary of state', 'Secretary of State'],
#  82: ['writer', 'poet', 'lyricist'],
#  83: ['Brazil', 'Brazilian Portuguese'],
#  84: ['aspect of history', 'study of history'],
#  85: [],
#  86: ['early childhood',
#   'adolescence',
#   'preadolescence',
#   'Childhood',
#   'sociology of childhood'],
#  87: [],
#  88: ['Roman Empire', 'Ancient Rome', 'Roman province'],
#  89: ['Sweden',
#   'Finland',
#   'Russia',
#   'Estonia',
#   'Latvia',
#   'Lithuania',
#   'Poland',
#   'Germany',
#   'Denmark',
#   'marginal sea',
#   'Gulf of Finland',
#   'Gulf of Riga',
#   'Gdańsk Bay',
#   'Baltic Proper',
#   'Bothnian Sea',
#   'Sea of Åland',
#   'Archipelago Sea'],
#  90: ['Josefa'],
#  91: ['Tunisia', 'governorate of Tunisia'],
#  92: ['association football kit'],
#  93: ['Schwarze Berge'],
#  94: ['Dallas'],
#  95: ['March 1',
#   'March 2',
#   'March 3',
#   'March 4',
#   'March 5',
#   'March 6',
#   'March 7',
#   'March 8',
#   'March 9',
#   'March 10',
#   'March 11',
#   'March 12',
#   'March 13',
#   'March 14',
#   'March 15',
#   'March 16',
#   'March 17',
#   'March 18',
#   'March 19',
#   'March 20',
#   'March 21',
#   'March 22',
#   'March 23',
#   'March 24',
#   'March 25',
#   'March 26',
#   'March 27',
#   'March 28',
#   'March 29',
#   'March 30',
#   'March 31',
#   'Marzec',
#   'März'],
#  96: ['politician', 'governor of Sergipe'],
#  97: ['obsolete currency', 'historical pound'],
#  98: [],
#  99: ['French', 'Französisch', 'Fransk', 'フランス語学']}

# %%
df['ABSTRACT_VALID'] = list(abstract_valid_answers.values())
df['ANSWER'] = answers

# %%
df
# Out:
#                                    GENERATED_QUESTION     ITEM_1    ITEM_2  \
# 0   What is the seal described by the country that...   Q4871749       Q30
# 1   What is the author of the national anthem of t...   Q5248175      Q145
# 2   What is the main article of the list that is t...    Q669125     Q9726
# 3   What is the geography associated with the coun...   Q3974535  Q1237470
# 4   What is the location of the headquarters of th...   Q1721298     Q2736
# ..                                                ...        ...       ...
# 95  What is the name day associated with the first...     Q76535   Q292691
# 96  What is the head of government of the administ...   Q2084020   Q170578
# 97  What is the currency used by the country that ...   Q7497242     Q1033
# 98  What is the history of the writing system used...   Q6174806  Q5576697
# 99  What is the language of the version for the ot...  Q17579913  Q6298851
#
#        ITEM_3     ITEM_4 PROP_1 PROP_2 PROP_3  \
# 0     Q171663     Q14213    P17   P418  P2378
# 1      Q40807   Q1606590    P27    P85    P50
# 2    Q3047934    Q207628    P86  P1455   P360
# 3         Q38    Q216989   P175   P495  P2633
# 4     Q253414        Q72   P641  P3719   P159
# ..        ...        ...    ...    ...    ...
# 95      Q2390       Q110   P735  P1750   P361
# 96     Q43783  Q10304754    P19   P131     P6
# 97   Q5440850   Q1485655    P27   P155    P38
# 98      Q8229   Q3772237   P734   P282  P2184
# 99  Q18180970       Q150   P735  P1560   P407
#
#                                        ABSTRACT_VALID  \
# 0            [secretary of state, Secretary of State]
# 1                                          [composer]
# 2   [musical work, composition, musical work/compo...
# 3                        [Italy, geography of Europe]
# 4   [Zürich District, Greater Zurich Area, Zurich ...
# ..                                                ...
# 95  [March 1, March 2, March 3, March 4, March 5, ...
# 96                  [politician, governor of Sergipe]
# 97              [obsolete currency, historical pound]
# 98                                                 []
# 99              [French, Französisch, Fransk, フランス語学]
#
#                               ANSWER
# 0   United States Secretary of State
# 1                        Henry Carey
# 2              composed musical work
# 3                 geography of Italy
# 4                             Zürich
# ..                               ...
# 95                             March
# 96                   Jackson Barreto
# 97                    Nigerian pound
# 98     history of the Latin alphabet
# 99                            French
#
# [100 rows x 10 columns]

# %%
df.to_csv('outputs/simple_multihop_examples_with_abstract_valid3.csv', index=False)

# %%
print(prompts_data[1][0])
# Out:
# Given the following question and a valid answer, identify all suitable candidates from the provided options that can also serve as valid answers to the question. Note that there may be multiple correct answers.
#
# Question:
# What is the author of the national anthem of the country that Deborah Baxter is a citizen of?
#
# Valid Answer:
# Henry Carey
#
# Options:
# ['human', 'poet', 'composer', 'writer']
#
# Respond with a JSON object containing a list of the selected options under the key 'answer'. If no suitable options are present, return an empty list.

# %%
json.loads(responses[1][0])
# Out:
# {'answer': ['poet', 'composer', 'writer']}

# %%
qid = 'Q6366688' #'Q76' 
abstraction_nodes = get_abstraction_nodes(qid, wikidata_properties)
abstraction_nodes
# Out:
# {'Geospatial Information': {'Moving Up the Hierarchy': ['Q18094', 'Q5684342'],
#   'Moving Down the Hierarchy': ['Q6739512'],
#   'Lateral Connections': ['Q6739512'],
#   'General Context': ['Q30', 'Q16917']},
#  'Occupation and Professional Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': []},
#  'Temporal Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': []},
#  'Biological and Taxonomic Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']},
#  'Cultural and Creative Work': {'Moving Up the Hierarchy': [],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']},
#  'Historical and Event Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': ['Q16917'],
#   'Lateral Connections': [],
#   'General Context': ['Q6739512']},
#  'Organizational Information': {'Moving Up the Hierarchy': ['Q5684342',
#    'Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']},
#  'Literary and Bibliographic Information': {'Moving Up the Hierarchy': [],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']},
#  'Scientific and Technical Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']},
#  'Social and Demographic Information': {'Moving Up the Hierarchy': ['Q5684342'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['Q16917']}}

# %%
abstraction_nodes_names = convert_abstraction_qids_to_labels(abstraction_nodes)

# %%
abstraction_nodes_names
# Out:
# {'Geospatial Information': {'Moving Up the Hierarchy': ['Honolulu',
#    'Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': ['Makiki'],
#   'Lateral Connections': ['Makiki'],
#   'General Context': ['United States of America', 'hospital']},
#  'Occupation and Professional Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': []},
#  'Temporal Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': []},
#  'Biological and Taxonomic Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']},
#  'Cultural and Creative Work': {'Moving Up the Hierarchy': [],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']},
#  'Historical and Event Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': ['hospital'],
#   'Lateral Connections': [],
#   'General Context': ['Makiki']},
#  'Organizational Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health',
#    'Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']},
#  'Literary and Bibliographic Information': {'Moving Up the Hierarchy': [],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']},
#  'Scientific and Technical Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']},
#  'Social and Demographic Information': {'Moving Up the Hierarchy': ['Hawaii Pacific Health'],
#   'Moving Down the Hierarchy': [],
#   'Lateral Connections': [],
#   'General Context': ['hospital']}}

# %%
combined_abstraction_list = []
for key, sub_dict in abstraction_nodes_names.items():
    for sub_key, value in sub_dict.items():
        combined_abstraction_list.extend(value)

# %%
combined_abstraction_list = list(set(combined_abstraction_list))

# %%
combined_abstraction_list
# Out:
# ['hospital',
#  'Honolulu',
#  'Makiki',
#  'United States of America',
#  'Hawaii Pacific Health']

# %%
q = 'Where was the 44th president of the United States born?'
prompt = get_abstraction_mcq_prompt(q, combined_abstraction_list)

# %%
print(prompt)
# Out:
# For the following question, choose all suitable candidates from the provided options that can reasonably asnwer the question:
#
# Question:
# Where was the 44th president of the United States born?
#
# Options:
# ['hospital', 'Honolulu', 'Makiki', 'United States of America', 'Hawaii Pacific Health']
#
# Respond with a JSON object with 'answer' key containing a list of the selected options, or an empty list if no suitable options are present.

# %%
response = query_openai_model(prompt)

# %%
json.loads(response[0])
# Out:
# {'answer': ['Honolulu', 'United States of America']}

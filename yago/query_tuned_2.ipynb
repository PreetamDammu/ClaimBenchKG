# %% [markdown]
# # Testing Queries
#
# Note: For now, we are lucky that the imports work, because we are using relative imports, and at one point, it will cause errors.

# %% [markdown]
# ## IMPORTS

# %%
import os
import sys
import random
import requests
import argparse
from typing import List, Set

import numpy as np
import pandas as pd

# %%
from db.yagodb import YagoDB
from db.constants.main import YAGO_ALL_ENTITY_COUNT, YAGO_FACTS_ENTITY_COUNT
from db.functions.entity import get_random_entities_query

# %%
from kg.query import get_triples_multiple_subjects_query, get_description_multiple_entities_query, query_kg, get_triples_from_response

# %%
from utils.constants import YAGO_ENTITY_STORE_DB_PATH, YAGO_PREFIXES_PATH, YAGO_ENDPOINT_URL
from utils.prefix import get_prefixes, get_url_from_prefix_and_id
from utils.random_walk2 import SPARQL_COLUMNS_DICT, RandomWalk2

# %% [markdown]
# ### CONSTANTS

# %% [markdown]
# ### FUNCTIONS

# %% [markdown]
# ### Experiment Single Walks

# %%
yago_db = YagoDB(YAGO_ENTITY_STORE_DB_PATH)

# %%
random_walk_2 = RandomWalk2(yago_db)

# %%
entities_df = random_walk_2.random_walk_description_batch(num_of_entities=10, depth=3)

# %%
entities_df
# Out:
#                                              entity0  \
# 0  http://yago-knowledge.org/resource/Haddington_...
# 1  http://yago-knowledge.org/resource/Arctictenas...
# 2  http://yago-knowledge.org/resource/Kedarpur_Br...
# 3  http://yago-knowledge.org/resource/Islamic_Fou...
# 4  http://yago-knowledge.org/resource/Elke_Franck...
# 5  http://yago-knowledge.org/resource/Sophora_pro...
# 6  http://yago-knowledge.org/resource/Huaxi_Shuik...
# 7      http://yago-knowledge.org/resource/Lazar_Paču
# 8  http://yago-knowledge.org/resource/Afgan-Memor...
# 9  http://yago-knowledge.org/resource/Ogle_Blg-Ec...
#
#                                         description0  \
# 0  architectural structure in East Lothian, Scotl...
# 1                                    genus of fishes
# 2                                                NaN
# 3  school in Villa Park, DuPage County, Illinois,...
# 4                                                NaN
# 5                                   species of plant
# 6            reservoir in People's Republic of China
# 7                                                NaN
# 8                                                NaN
# 9                              eclipsing binary star
#
#                                         predicate1  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                    http://schema.org/parentTaxon
# 2       http://yago-knowledge.org/resource/ownedBy
# 3                       http://schema.org/location
# 4                         http://schema.org/gender
# 5  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6                       http://schema.org/location
# 7                                             None
# 8  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                              entity1  \
# 0  http://yago-knowledge.org/resource/HumanMadeGe...
# 1  http://yago-knowledge.org/resource/Ctenaspidid...
# 2      http://yago-knowledge.org/resource/India_Post
# 3   http://yago-knowledge.org/resource/United_States
# 4  http://yago-knowledge.org/resource/Female__u00...
# 5                            http://schema.org/Taxon
# 6          http://yago-knowledge.org/resource/Fujian
# 7                                               None
# 8         http://yago-knowledge.org/resource/Website
# 9  http://yago-knowledge.org/resource/Eclipsing_b...
#
#                                         description1  \
# 0              alterations to land created by people
# 1                                   family of fishes
# 2         Government-operated Postal system in India
# 3                           country in North America
# 4  to be used in 'sex or gender' (P21) to indicat...
# 5  group of one or more organism(s), which a taxo...
# 6                                  province of China
# 7                                                NaN
# 8  set of related web pages served from a single ...
# 9  binary star in which the orbit plane of the tw...
#
#                                         predicate2  \
# 0             http://www.w3.org/2002/07/owl#sameAs
# 1                    http://schema.org/parentTaxon
# 2                       http://schema.org/location
# 3                       http://schema.org/memberOf
# 4       http://www.w3.org/2000/01/rdf-schema#label
# 5       http://www.w3.org/2002/07/owl#disjointWith
# 6       http://yago-knowledge.org/resource/capital
# 7                                             None
# 8  http://www.w3.org/2000/01/rdf-schema#subClassOf
# 9  http://www.w3.org/2000/01/rdf-schema#subClassOf
#
#                                              entity2  \
# 0  http://yago-knowledge.org/resource/HumanMadeGe...
# 1   http://yago-knowledge.org/resource/Cyathaspidida
# 2       http://yago-knowledge.org/resource/New_Delhi
# 3  http://yago-knowledge.org/resource/Universal_P...
# 4                                             žeńska
# 5                     http://schema.org/CreativeWork
# 6          http://yago-knowledge.org/resource/Fuzhou
# 7                                               None
# 8  http://yago-knowledge.org/resource/Online_Publ...
# 9     http://yago-knowledge.org/resource/Binary_star
#
#                                         description2
# 0              alterations to land created by people
# 1                           order of fishes (fossil)
# 2                                   capital of India
# 3  specialized agency of the United Nations focus...
# 4                                                NaN
# 5                                  artistic creation
# 6             capital city of Fujian province, China
# 7                                                NaN
# 8                        work manifested in Internet
# 9                star system consisting of two stars

# %%
entities_df.iloc[2]['entity0']
# Out:
# 'http://yago-knowledge.org/resource/Kedarpur_Branch_Post_Office_Q69942706'

# %%
random_entities_query = get_random_entities_query(num_of_entities=10)
entities = yago_db.query(random_entities_query)
entities_df = pd.DataFrame([f"{entity[1]}" for entity in entities], columns=["entity0"])

# %%
entities_df.head()
# Out:
#                                              entity0
# 0  http://yago-knowledge.org/resource/Phaulernis_...
# 1  http://yago-knowledge.org/resource/The_Regiona...
# 2  http://yago-knowledge.org/resource/Cleburne_Sp...
# 3  http://yago-knowledge.org/resource/Church_Of_T...
# 4  http://yago-knowledge.org/resource/Monochamus_...

# %%
get_counts_for_entities(yago_db = yago_db, entity_series = entities_df["entity0"], entity_column_label = "entity0")
# Out:
#                                              entity0  count
# 0  http://yago-knowledge.org/resource/Phaulernis_...      8
# 1  http://yago-knowledge.org/resource/The_Regiona...      5
# 2  http://yago-knowledge.org/resource/Cleburne_Sp...      5
# 3  http://yago-knowledge.org/resource/Church_Of_T...      7
# 4  http://yago-knowledge.org/resource/Monochamus_...     13
# 5  http://yago-knowledge.org/resource/Hilarograph...     10
# 6  http://yago-knowledge.org/resource/Steindamm_Q...      9
# 7  http://yago-knowledge.org/resource/Tyc_3162-16...      4
# 8        http://yago-knowledge.org/resource/Q6668313      5
# 9       http://yago-knowledge.org/resource/Q83846536      6

# %%
random_walks = random_walks_multiple(yago_db, num_of_entities=1000, depth=3)

# %%
random_walks
# Out:
#                                                entity0  \
# 0    http://yago-knowledge.org/resource/Anton_von_H...
# 1    http://yago-knowledge.org/resource/Danger_Cat_...
# 2    http://yago-knowledge.org/resource/Clivina_ang...
# 3    http://yago-knowledge.org/resource/Zfourge_Cdf...
# 4    http://yago-knowledge.org/resource/Laura_L_Hoo...
# ..                                                 ...
# 995  http://yago-knowledge.org/resource/Iras_17314-...
# 996      http://yago-knowledge.org/resource/Q108402592
# 997  http://yago-knowledge.org/resource/Josiah_L_Ha...
# 998  http://yago-knowledge.org/resource/Payson_R_u0...
# 999  http://yago-knowledge.org/resource/Louis_Henri...
#
#                                           predicate1  \
# 0                    http://schema.org/knowsLanguage
# 1    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4               http://www.w3.org/2002/07/owl#sameAs
# ..                                               ...
# 995             http://www.w3.org/2002/07/owl#sameAs
# 996                       http://schema.org/location
# 997                       http://schema.org/worksFor
# 998                         http://schema.org/gender
# 999                    http://schema.org/nationality
#
#                                                entity1  \
# 0    http://yago-knowledge.org/resource/German_lang...
# 1    http://yago-knowledge.org/resource/Band__u0028...
# 2                              http://schema.org/Taxon
# 3            http://yago-knowledge.org/resource/Galaxy
# 4             http://www.wikidata.org/entity/Q90724654
# ..                                                 ...
# 995           http://www.wikidata.org/entity/Q83948820
# 996           http://yago-knowledge.org/resource/Syria
# 997  http://yago-knowledge.org/resource/Huntsman_Ca...
# 998     http://yago-knowledge.org/resource/Male_gender
# 999          http://yago-knowledge.org/resource/France
#
#                                           predicate2  \
# 0                      http://schema.org/nationality
# 1               http://www.w3.org/2002/07/owl#sameAs
# 2                      http://schema.org/parentTaxon
# 3               http://www.w3.org/2002/07/owl#sameAs
# 4                           http://schema.org/gender
# ..                                               ...
# 995             http://www.w3.org/2002/07/owl#sameAs
# 996                       http://schema.org/location
# 997  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 998  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 999                     http://schema.org/birthPlace
#
#                                                entity2
# 0           http://yago-knowledge.org/resource/Germany
# 1             http://www.wikidata.org/entity/Q33106451
# 2           http://yago-knowledge.org/resource/Clivina
# 3             http://www.wikidata.org/entity/Q77396352
# 4    http://yago-knowledge.org/resource/Female__u00...
# ..                                                 ...
# 995           http://www.wikidata.org/entity/Q83948820
# 996           http://yago-knowledge.org/resource/Syria
# 997      http://yago-knowledge.org/resource/Researcher
# 998         http://yago-knowledge.org/resource/Painter
# 999      http://yago-knowledge.org/resource/Damvillers
#
# [1000 rows x 5 columns]
